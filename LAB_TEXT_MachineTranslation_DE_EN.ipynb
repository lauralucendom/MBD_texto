# %% [markdown]
# ### 1. Import Required Libraries

# %%
import string
import re
from numpy import array, argmax, random, take
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import GRU, Input, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional, Dropout, LSTM
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from keras.layers.embeddings import Embedding
from keras.optimizers import Adam
from keras.losses import sparse_categorical_crossentropy
from keras import optimizers
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_colwidth', 200)
from text import *

# %% [markdown]
# ### 2. Read Data
#
# En este primer paso, se indica el texto objeto de estudio. Este texto será el que se leerá y preprocesará a partir de las funciones definidas en el archivo _text.py_. Antes de ello, es necesario iniciar la clase __UTILS__ que recoge todas las funciones que se irán usando a medida que se avance en el notebook.
#
# Por tanto, se inicia la clase __UTILS__ y, posteriormente se indica el texto a estudiar. Una vez indicado, se llama a la función _read_data_ que permite la obtención de un array de pares inglés/alemán o inglés/español según el archivo indicado. Para este proyecto, se usará el archivo inglés/español y, por tanto, los pares del array serán pares __inglés/español__.

# %%
utils=UTILS()
# Out:
# Instancia de la clase UTILS creada

# %%
filename= "spa-eng/spa.txt"
data_eng_spa=utils.read_data(filename=filename)
data_eng_spa=data_eng_spa[:,:2]
print(len(data_eng_spa))
# Out:
# 122936

# %%
data_eng_spa[:50000,:]
# Out:
# array([['Go.', 'Ve.'],
#        ['Go.', 'Vete.'],
#        ['Go.', 'Vaya.'],
#        ...,
#        ['I am waiting for my driver.', 'Estoy esperando a mi chofer.'],
#        ['I appreciate all your help.', 'Aprecio toda tu ayuda.'],
#        ['I appreciate your interest.', 'Agradezco tu interés.']],
#       dtype='<U332')

# %% [markdown]
# Como se puede ver en las celdas anteriores, el array __data_eng_spa__ contiene 122936 entradas o pares de frases. Sin embargo, puesto a que entrenar tantas entradas puede llevar mucho tiempo, se usarán únicamente las primeras 50000 entradas con el fin de reducir el tiempo de entrenamiento.

# %%
data_eng_spa = data_eng_spa[:50000,:]
print(len(data_eng_spa))
# Out:
# 50000

# %% [markdown]
# ### 3. Text Pre-Processing

# %% [markdown]
# En esta sección, se hace uso de la función _text_preprocessing_ con el fin de eliminar los signos de puntuación así como pasar a minúscula cada una de las frases que componen el array disponible.

# %%
data_eng_spa_processed = utils.text_preprocessing(data_eng_spa)
data_eng_spa_processed
# Out:
# array([['go', 've'],
#        ['go', 'vete'],
#        ['go', 'vaya'],
#        ...,
#        ['i am waiting for my driver', 'estoy esperando a mi chofer'],
#        ['i appreciate all your help', 'aprecio toda tu ayuda'],
#        ['i appreciate your interest', 'agradezco tu interés']],
#       dtype='<U332')

# %% [markdown]
# Como se puede ver en el output de la celda anterior, las frases ya no contienen puntos al final de las mismas y, además, se encuentran en minúscula.
#
# Además, para alimentar los datos en un modelo Seq2Seq, es necesario convertir tanto las oraciones de entrada como las de salida en secuencias enteras de longitud fija. Antes de eso, se visualizan la longitud de las oraciones en la siguiente subsección _Text to Sequence Conversion_. Se capturan, por tanto, la longitud de todas las oraciones en dos listas separadas para inglés y alemán, respectivamente.

# %% [markdown]
# #### _Text to Sequence Conversion_

# %%
max_l1,max_l2,length_df = utils.get_length(data_eng_spa_processed)

# %%
print('Max length from the English text is: {}'.format(max_l1))
print('Max length from the German text is: {}'.format(max_l2))
length_df.head()
# Out:
# Max length from the English text is: 8
# Max length from the German text is: 12
#    eng  esp
# 0    1    1
# 1    1    1
# 2    1    1
# 3    1    1
# 4    1    1

# %%
length_df.eng.value_counts()
# Out:
# 4    17029
# 5    14568
# 3     9855
# 6     5055
# 2     2958
# 7      464
# 1       61
# 8       10
# Name: eng, dtype: int64

# %%
length_df.esp.value_counts()
# Out:
# 4     15354
# 3     12148
# 5     10449
# 2      4784
# 6      4608
# 7      1494
# 1       698
# 8       363
# 9        69
# 10       27
# 11        3
# 12        3
# Name: esp, dtype: int64

# %%
length_df.hist(bins = 30)
plt.show()

# %% [markdown]
# A partir de los resultados obtenidos en las celdas anteriores, se puede ver que la longitud máxima de las frases en __inglés__ es __8__, mientras que para las frases de __español__ la longitud máxima alcanzada es de __12__. Además, si se observa el histograma anterior, se puede concluir que para los dos casos las frases de una longitud de 4 palabras tienen una mayor frecuencia.
#
# Una vez estudiadas las longitudes de ambos idiomas, se procede a asignar una longitud fija a los datos. Para ello, se vectorizan los datos de texto usando la clase _Tokenizer()_ de _Keras_. Convertirá las oraciones en secuencias de números enteros. Luego esas secuencias se rellenarán con ceros para hacer que todas las secuencias tengan la misma longitud.
#
# La función _fit_on_texts_ que se usa en la función _tokenization_ definida en el archivo _text.py_ actualiza el vocabulario interno basado en una lista de textos. Este método crea el índice de vocabulario basado en la frecuencia de las palabras. Entonces, si le das algo como _"El gato se sentó en la alfombra"_, creará un diccionario como: wordindex[[el]] = 1; wordindex[[cat]] = 2 es palabra -> diccionario de índice, por lo que cada palabra obtiene un valor entero único. 0 está reservado para el __padding__. Por lo tanto, un número entero más bajo significa una palabra más frecuente (a menudo, las primeras son stop words porque aparecen muchas).

# %% [markdown]
# #### _Tokenization_

# %%
#Tokenizer aplicado a la columna eng (english)
eng_tokenized, eng_tokenizer = utils.tokenization(data_eng_spa_processed[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = 8
print('English Vocabulary Size: {}'.format(eng_vocab_size))
# Out:
# English Vocabulary Size: 6942

# %%
print(eng_tokenizer.word_counts)
# Out:
# , 1), ('miserable', 1), ('cores', 1), ('landline', 1), ('ram', 1), ('fried', 1), ('bruises', 2), ('press', 3), ('intrude', 1), ('outsider', 1), ('throwing', 1), ('730', 2), ('motherinlaw', 1), ('nuisance', 2), ('skill', 1), ('ace', 3), ('clubs', 1), ('teenage', 1), ('tour', 1), ('consequences', 1), ('npr', 1), ('proposition', 1), ('carols', 1), ('secretary', 3), ('corrections', 1), ('crash', 4), ('cooperation', 1), ('1000', 1), ('partly', 1), ('warmer', 4), ('thai', 3), ('reckon', 1), ('strongly', 1), ('refrain', 2), ('unicycle', 3), ('sawing', 2), ('shredded', 3), ('document', 5), ('cheaply', 1), ('spent', 4), ('stretched', 1), ('thoroughly', 1), ('tend', 2), ('dissuade', 1), ('traffic', 6), ('youtube', 1), ('kobe', 1), ('suggestions', 1), ('stress', 1), ('crossing', 2), ('chores', 2), ('emotionally', 1), ('drained', 1), ('faithful', 1), ('coast', 2), ('difficulties', 1), ('average', 2), ('eighth', 2), ('repairing', 1), ('resigning', 1), ('since', 3), ('checked', 1), ('priorities', 1), ('happier', 2), ('whoever', 3), ('recovering', 1), ('sixthirty', 1), ('manuscript', 1), ('restful', 1), ('freeze', 1), ('durable', 1), ('casual', 1), ('aberration', 1), ('occasion', 1), ('surely', 1), ('delicate', 2), ('quarter', 5), ('humid', 1), ('visible', 1), ('expression', 1), ('contract', 3), ('harmless', 1), ('safer', 1), ('import', 2), ('kennedy', 1), ('bottles', 1), ('madness', 1), ('opposed', 4), ('slavery', 2), ('lucks', 1), ('lychees', 1), ('childbirth', 1), ('eyelashes', 1), ('boyfriends', 1), ('pink', 5), ('curtains', 4), ('waterproof', 2), ('shedding', 1), ('major', 2), ('agriculture', 3), ('except', 2), ('praises', 2), ('mix', 1), ('weekends', 3), ('steep', 2), ('arriving', 1), ('drapes', 3), ('extend', 1), ('insert', 1), ('sum', 3), ('poland', 1), ('salaries', 1), ('increased', 2), ('dissolves', 2), ('8th', 1), ('snowwhite', 1), ('bathing', 2), ('blackmailing', 1), ('errand', 1), ('hardworking', 2), ('brooch', 1), ('proverbs', 1), ('solitary', 1), ('eighty', 2), ('prefers', 3), ('revealed', 3), ('uninterested', 1), ('telephoned', 2), ('unfit', 2), ('pairs', 1), ('jumping', 3), ('typos', 1), ('intrusion', 1), ('spell', 4), ('hazelnuts', 1), ('steel', 1), ('traps', 1), ('torturing', 1), ('follows', 1), ('sunlight', 2), ('sydney', 1), ('whichever', 4), ('applies', 2), ('edible', 1), ('liking', 3), ('distracts', 1), ('altogether', 2), ('current', 1), ('czar', 1), ('overthrown', 1), ('pope', 2), ('foul', 3), ('ambassador', 1), ('auction', 1), ('crawl', 1), ('balloons', 1), ('nest', 1), ('climates', 1), ('criminal', 2), ('wagged', 2), ('collar', 2), ('opening', 3), ('withered', 1), ('dusty', 2), ('cutting', 2), ('unbearable', 5), ('hen', 2), ('flames', 1), ('imposter', 2), ('backlit', 1), ('lagoon', 1), ('landing', 1), ('nights', 1), ('ceaseless', 1), ('odds', 2), ('organization', 1), ('pasty', 1), ('printer', 2), ('underway', 1), ('proverb', 1), ('level', 1), ('anchor', 2), ('snowstorm', 1), ('flooded', 1), ('title', 1), ('traffics', 1), ('congested', 1), ('trail', 1), ('undeniable', 1), ('endless', 1), ('muscles', 1), ('stiff', 3), ('sales', 2), ('hitches', 1), ('railroads', 1), ('burglary', 2), ('originals', 1), ('stink', 1), ('gathering', 1), ('mistreat', 1), ('themselves', 2), ('cautiously', 5), ('flattened', 1), ('passports', 2), ('chasing', 2), ('charged', 2), ('bolt', 1), ('fits', 1), ('nut', 1), ('whodunit', 1), ('tin', 1), ('bode', 2), ('sunshine', 1), ('terrifies', 1), ('starling', 1), ('zebras', 1), ('bandaged', 1), ('certainly', 4), ('chopped', 2), ('clicked', 1), ('admiration', 1), ('unthinkable', 1), ('97', 2), ('girlfriends', 2), ('unpacked', 1), ('skydiver', 1), ('cocaine', 2), ('guitarist', 2), ('sincere', 1), ('social', 1), ('drinker', 1), ('braver', 1), ('feeding', 3), ('nauseous', 1), ('handball', 1), ('hyperventilating', 1), ('clubhouse', 1), ('hall', 3), ('warehouse', 1), ('insanely', 1), ('manipulating', 1), ('bachelor', 1), ('sociable', 1), ('experimenting', 1), ('lens', 1), ('events', 1), ('burgers', 2), ('h ...

# %%
for sample_i, (sent, token_sent) in enumerate(zip(data_eng_spa_processed[:,0], eng_tokenized)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(sent))
    print('  Output: {}'.format(token_sent))
# Out:
#  in x
#   Input:  he speaks english fluently
#   Output: [8, 580, 328, 2894]
# Sequence 49785 in x
#   Input:  he speaks a little english
#   Output: [8, 580, 5, 226, 328]
# Sequence 49786 in x
#   Input:  he started washing his car
#   Output: [8, 386, 1280, 41, 81]
# Sequence 49787 in x
#   Input:  he stayed here for a while
#   Output: [8, 891, 38, 35, 5, 808]
# Sequence 49788 in x
#   Input:  he still has much to learn
#   Output: [8, 115, 45, 119, 7, 479]
# Sequence 49789 in x
#   Input:  he stood there for a while
#   Output: [8, 864, 55, 35, 5, 808]
# Sequence 49790 in x
#   Input:  he stopped to talk to them
#   Output: [8, 458, 7, 162, 7, 128]
# Sequence 49791 in x
#   Input:  he stopped to talk to them
#   Output: [8, 458, 7, 162, 7, 128]
# Sequence 49792 in x
#   Input:  he studies chinese as well
#   Output: [8, 1387, 1058, 118, 84]
# Sequence 49793 in x
#   Input:  he thanked me for the gift
#   Output: [8, 2348, 10, 35, 6, 1148]
# Sequence 49794 in x
#   Input:  he thanked me for the gift
#   Output: [8, 2348, 10, 35, 6, 1148]
# Sequence 49795 in x
#   Input:  he told me all the details
#   Output: [8, 182, 10, 52, 6, 1442]
# Sequence 49796 in x
#   Input:  he told me to wash my face
#   Output: [8, 182, 10, 7, 693, 13, 435]
# Sequence 49797 in x
#   Input:  he told me when to say yes
#   Output: [8, 182, 10, 164, 7, 134, 553]
# Sequence 49798 in x
#   Input:  he touched me on the cheek
#   Output: [8, 1784, 10, 34, 6, 4569]
# Sequence 49799 in x
#   Input:  he tumbled down the stairs
#   Output: [8, 6921, 123, 6, 1261]
# Sequence 49800 in x
#   Input:  he turned pale at the news
#   Output: [8, 396, 1060, 46, 6, 484]
# Sequence 49801 in x
#   Input:  he turned up an hour later
#   Output: [8, 396, 48, 70, 703, 382]
# Sequence 49802 in x
#   Input:  he visited kyoto last year
#   Output: [8, 1322, 1677, 208, 589]
# Sequence 49803 in x
#   Input:  he volunteered to help her
#   Output: [8, 2048, 7, 68, 61]
# Sequence 49804 in x
#   Input:  he waited for him until 10
#   Output: [8, 723, 35, 42, 633, 1743]
# Sequence 49805 in x
#   Input:  he walked all the way home
#   Output: [8, 622, 52, 6, 171, 89]
# Sequence 49806 in x
#   Input:  he wants me to go with him
#   Output: [8, 159, 10, 7, 32, 57, 42]
# Sequence 49807 in x
#   Input:  he warned me of the danger
#   Output: [8, 1602, 10, 29, 6, 604]
# Sequence 49808 in x
#   Input:  he was a god to his people
#   Output: [8, 15, 5, 700, 7, 41, 298]
# Sequence 49809 in x
#   Input:  he was almost hit by a car
#   Output: [8, 15, 304, 412, 136, 5, 81]
# Sequence 49810 in x
#   Input:  he was angry with his wife
#   Output: [8, 15, 233, 57, 41, 334]
# Sequence 49811 in x
#   Input:  he was arrested for murder
#   Output: [8, 15, 1622, 35, 1174]
# Sequence 49812 in x
#   Input:  he was attacked by a shark
#   Output: [8, 15, 1775, 136, 5, 4572]
# Sequence 49813 in x
#   Input:  he was attacked by a shark
#   Output: [8, 15, 1775, 136, 5, 4572]
# Sequence 49814 in x
#   Input:  he was aware of the danger
#   Output: [8, 15, 909, 29, 6, 604]
# Sequence 49815 in x
#   Input:  he was baptized a catholic
#   Output: [8, 15, 4189, 5, 2643]
# Sequence 49816 in x
#   Input:  he was born in switzerland
#   Output: [8, 15, 548, 24, 6922]
# Sequence 49817 in x
#   Input:  he was bound hand and foot
#   Output: [8, 15, 2849, 367, 106, 989]
# Sequence 49818 in x
#   Input:  he was caught in an ambush
#   Output: [8, 15, 443, 24, 70, 3744]
# Sequence 49819 in x
#   Input:  he was clearly embarrassed
#   Output: [8, 15, 1024, 1163]
# Sequence 49820 in x
#   Input:  he was clearly embarrassed
#   Output: [8, 15, 1024, 1163]
# Sequence 49821 in x
#   Input:  he was completely worn out
#   Output: [8, 15, 833, 841, 67]
# Sequence 49822 in x
#   Input:  he was completely worn out
#   Output: [8, 15, 833, 841, 67]
# Sequence 49823 in x
#   Input:  he was crossing the street
#   Output: [8, 15, 4358, 6, 965]
# Sequence 49824 in x
#   Input:  he was desperate to escape
#   Output: [8, 15, 1871, 7, 882]
# Sequence 49825 in x
#   Input:  he was elected mayor again
#   Output: [8, 15, 1981, 1435, 144]
# Sequence 49826 in x
#   Input:  he was killed with a sword
#   Output: [8, 15, 608, 57, 5, 2633]
# Sequence 49827 in x
#   Input:  he was paid 10000 dollars
#   Output: [8, 15, 537, 4156, 970]
# Sequence 49828 in x
#   Input:  he was popular with voters
#   Output: [8, 15, 1612, 57, 6923]
# Sequence 49829 in x
#   Input:  he was reading a newspaper
#   Output: [8, 15, 405, 5, 1224]
# Sequence 49830 in x
#   Input:  he was run over and killed
#   Output: [8, 15, 352, 219, 106, 608]
# Sequence 49831 in x
#   Input:  he was seeking reelection
#   Output: [8, 15, 4446, 4520]
# Sequence 49832 in x
#   Input:  he was sentenced to prison
#   Output: [8, 15, 3501, 7, 1102]
# Sequence 49833 in x
#   Input:  he was wounded by a bullet
#   Output: [8, 15, 1631, 136, 5, 2304]
# Sequence 49834 in x
#   Input:  he was wounded by a bullet
#   Output: [8, 15, 1631, 136, 5, 2304]
# Sequence 49835 in x
#   Input:  he was wounded in the head
#   Output: [8, 15, 1631, 24, 6, 733]
# Sequence 49836 in x
#   Input:  he weighs about 300 pounds
#   Output: [8, 6924, 90, 1702, 4568]
# Sequence 49837 in x
#   Input:  he went to tokyo yesterday
#   Output: [8, 127, 7, 824, 282]
# Sequence 49838 in x
#   Input:  he will be back in an hour
#   Output: [8, 64, 30, 93, 24, 70, 703]
# Sequence 49839 in x
#   Input:  he will be here any moment
#   Output: [8, 64, 30, 38, 187, 606]
# Sequence 49840 in x
#   Input:  he will be ruined for life
#   Output: [8, 64, 30, 1312, 35, 234]
# Sequence 49841 in x
#   Input:  he will be waiting for you
#   Output: [8, 64, 30, 406, 35, 2]
# Sequence 49842 in x
#   Input:  he will be waiting for you
#   Output: [8, 64, 30, 406, 35, 2]
# Sequence 49843 in x
#   Input:  he will get well very soon
#   Output: [8, 64, 56, 84, 40, 268]
# Sequence 49844 in x
#   Input:  he will make a good doctor
#   Output: [8, 64, 154, 5, 59, 317]
# Sequence 49845 in x
#   Input:  he will pay for everything
#   Output: [8, 64, 203, 35, 193]
# Sequence 49846 in x
#   Input:  he won the prize last week
#   Output: [8, 420, 6, 1319, 208, 330]
# Sequence 49847 in x
#   Input:  he worked harder than ever
#   Output: [8, 577, 1335, 239, 392]
# Sequence 49848 in x
#   Input:  he works eight hours a day
#   Output: [8, 375, 1295, 1001, 5, 150]
# Sequence 49849 in x
#   Input:  he works in the laboratory
#   Output: [8, 375, 24, 6, 6925]
# Sequence 49850 in x
#   Input:  he would have to surrender
#   Output: [8, 178, 17, 7, 2041]
# Sequence 49851 in x
#   Input:  hes a lawabiding citizen
#   Output: [79, 5, 4573, 1444]
# Sequence 49852 in x
#   Input:  hes a lawabiding citizen
#   Output: [79, 5, 4573, 1444]
# Sequence 49853 in x
#   Input:  hes a man you can rely on
#   Output: [79, 5, 165, 2, 25, 1939, 34]
# Sequence 49854 in x
#   Input:  hes a teacher and so am i
#   Output: [79, 5, 335, 106, 82, 66, 1]
# Sequence 49855 in x
#   Input:  hes a very selfish person
#   Output: [79, 5, 40, 1485, 348]
# Sequence 49856 in x
#   Input:  hes addicted to junk food
#   Output: [79, 3412, 7, 3493, 254]
# Sequence 49857 in x
#   Input:  hes always late for class
#   Output: [79, 177, 180, 35, 1000]
# Sequence 49858 in x
#   Input:  hes always reading comics
#   Output: [79, 177, 405, 6926]
# Sequence 49859 in x
#   Input:  hes always short of money
#   Output: [79, 177, 473, 29, 105]
# Sequence 49860 in x
#   Input:  hes always short of money
#   Output: [79, 177, 473, 29, 105]
# Sequence 49861 in x
#   Input:  hes always short of money
#   Output: [79, 177, 473, 29, 105]
# Sequence 49862 in x
#   Input:  hes definitely not coming
#   Output: [79, 2002, 27, 266]
# Sequence 49863 in x
#   Input:  hes digging his own grave
#   Output: [79, 1604, 41, 342, 2118]
# Sequence 49864 in x
#   Input:  hes digging his own grave
#   Output: [79, 1604, 41, 342, 2118]
# Sequence 49865 in x
#   Input:  hes doing something there
#   Output: [79, 221, 152, 55]
# Sequence 49866 in x
#   Input:  hes eager to speak to you
#   Output: [79, 2211, 7, 135, 7, 2]
# Sequence 49867 in x
#   Input:  hes going back to america
#   Output: [79, 92, 93, 7, 915]
# Sequence 49868 in x
#   Input:  hes perfect at everything
#   Output: [79, 509, 46, 193]
# Sequence 49869 in x
#   Input:  hes rich rather than poor
#   Output: [79, 345, 674, 239, 696]
# Sequence 49870 in x
#   Input:  hes smarter than they are
#   Output: [79, 1820, 239, 36, 16]
# Sequence 49871 in x
#   Input:  hes stupid and irrational
#   Output: [79, 341, 106, 6927]
# Sequence 49872 in x
#   Input:  hes the captain of a team
#   Output: [79, 6, 2168, 29, 5, 587]
# Sequence 49873 in x
#   Input:  hes the fifth man in line
#   Output: [79, 6, 4528, 165, 24, 926]
# Sequence 49874 in x
#   Input:  hes writing a long letter
#   Output: [79, 628, 5, 198, 452]
# Sequence 49875 in x
#   Input:  he too would visit china
#   Output: [8, 76, 178, 648, 1572]
# Sequence 49876 in x
#   Input:  help is already on the way
#   Output: [68, 4, 218, 34, 6, 171]
# Sequence 49877 in x
#   Input:  help me get out of the car
#   Output: [68, 10, 56, 67, 29, 6, 81]
# Sequence 49878 in x
#   Input:  help me get out of the car
#   Output: [68, 10, 56, 67, 29, 6, 81]
# Sequence 49879 in x
#   Input:  help me learn how to drive
#   Output: [68, 10, 479, 47, 7, 337]
# Sequence 49880 in x
#   Input:  her books sell pretty well
#   Output: [61, 297, 812, 260, 84]
# Sequence 49881 in x
#   Input:  her eyes filled with tears
#   Output: [61, 347, 2890, 57, 1203]
# Sequence 49882 in x
#   Input:  her eyes filled with tears
#   Output: [61, 347, 2890, 57, 1203]
# Sequence 49883 in x
#   Input:  her family moved to brazil
#   Output: [61, 398, 663, 7, 3074]
# Sequence 49884 in x
#   Input:  her hair is wet with sweat
#   Output: [61, 331, 4, 889, 57, 2339]
# Sequence 49885 in x
#   Input:  her house is near the park
#   Output: [61, 149, 4, 757, 6, 680]
# Sequence 49886 in x
#   Input:  her look expressed her joy
#   Output: [61, 98, 6928, 61, 1752]
# Sequence 49887 in x
#   Input:  her name was spelled wrong
#   Output: [61, 190, 15, 4574, 186]
# Sequence 49888 in x
#   Input:  her name was spelled wrong
#   Output: [61, 190, 15, 4574, 186]
# Sequence 49889 in x
#   Input:  her old cat is still alive
#   Output: [61, 147, 246, 4, 115, 584]
# Sequence 49890 in x
#   Input:  her speech was full of wit
#   Output: [61, 1451, 15, 483, 29, 6929]
# Sequence 49891 in x
#   Input:  her vanity knows no bounds
#   Output: [61, 6930, 205, 62, 6931]
# Sequence 49892 in x
#   Input:  her villa sits on the hill
#   Output: [61, 6932, 6933, 34, 6, 1819]
# Sequence 49893 in x
#   Input:  here is one of my pictures
#   Output: [38, 4, 75, 29, 13, 1010]
# Sequence 49894 in x
#   Input:  here is one of my pictures
#   Output: [38, 4, 75, 29, 13, 1010]
# Sequence 49895 in x
#   Input:  heres my telephone number
#   Output: [768, 13, 1225, 642]
# Sequence 49896 in x
#   Input:  hey i need to talk to you
#   Output: [708, 1, 51, 7, 162, 7, 2]
# Sequence 49897 in x
#   Input:  his breathing became faint
#   Output: [41, 1636, 486, 2026]
# Sequence 49898 in x
#   Input:  his car is similar to mine
#   Output: [41, 81, 4, 2195, 7, 220]
# Sequence 49899 in x
#   Input:  his death surprised us all
#   Output: [41, 565, 705, 77, 52]
# Sequence 49900 in x
#   Input:  his effort will bear fruit
#   Output: [41, 2834, 64, 867, 895]
# Sequence 49901 in x
#   Input:  his eyes filled with tears
#   Output: [41, 347, 2890, 57, 1203]
# Sequence 49902 in x
#   Input:  his father was a policeman
#   Output: [41, 200, 15, 5, 1162]
# Sequence 49903 in x
#   Input:  his girlfriend is japanese
#   Output: [41, 720, 4, 475]
# Sequence 49904 in x
#   Input:  his girlfriend is japanese
#   Output: [41, 720, 4, 475]
# Sequence 49905 in x
#   Input:  his joke made us all laugh
#   Output: [41, 523, 114, 77, 52, 701]
# Sequence 49906 in x
#   Input:  his lectures are very long
#   Output: [41, 4575, 16, 40, 198]
# Sequence 49907 in x
#   Input:  his lectures are very long
#   Output: [41, 4575, 16, 40, 198]
# Sequence 49908 in x
#   Input:  his meaning is quite plain
#   Output: [41, 6934, 4, 444, 2183]
# Sequence 49909 in x
#   Input:  his name is familiar to us
#   Output: [41, 190, 4, 1771, 7, 77]
# Sequence 49910 in x
#   Input:  his old cat is still alive
#   Output: [41, 147, 246, 4, 115, 584]
# Sequence 49911 in x
#   Input:  his prophecy was fulfilled
#   Output: [41, 2425, 15, 4548]
# Sequence 49912 in x
#   Input:  his sister became a doctor
#   Output: [41, 460, 486, 5, 317]
# Sequence 49913 in x
#   Input:  his son is eight years old
#   Output: [41, 379, 4, 1295, 671, 147]
# Sequence 49914 in x
#   Input:  his son trembled with fear
#   Output: [41, 379, 3427, 57, 750]
# Sequence 49915 in x
#   Input:  his sons do as they please
#   Output: [41, 1066, 11, 118, 36, 53]
# Sequence 49916 in x
#   Input:  his technique was the best
#   Output: [41, 4527, 15, 6, 319]
# Sequence 49917 in x
#   Input:  his work is making watches
#   Output: [41, 94, 4, 645, 2351]
# Sequence 49918 in x
#   Input:  holland is a small country
#   Output: [6935, 4, 5, 474, 934]
# Sequence 49919 in x
#   Input:  honesty doesnt always pay
#   Output: [2415, 129, 177, 203]
# Sequence 49920 in x
#   Input:  how about we meet tomorrow
#   Output: [47, 90, 20, 346, 197]
# Sequence 49921 in x
#   Input:  how about we meet tomorrow
#   Output: [47, 90, 20, 346, 197]
# Sequence 49922 in x
#   Input:  how can i change your mind
#   Output: [47, 25, 1, 476, 21, 316]
# Sequence 49923 in x
#   Input:  how can i start the engine
#   Output: [47, 25, 1, 286, 6, 1746]
# Sequence 49924 in x
#   Input:  how come he didnt show up
#   Output: [47, 54, 8, 69, 299, 48]
# Sequence 49925 in x
#   Input:  how did the secret get out
#   Output: [47, 33, 6, 441, 56, 67]
# Sequence 49926 in x
#   Input:  how did this happen to you
#   Output: [47, 33, 12, 305, 7, 2]
# Sequence 49927 in x
#   Input:  how did you find that book
#   Output: [47, 33, 2, 188, 19, 107]
# Sequence 49928 in x
#   Input:  how did you get this money
#   Output: [47, 33, 2, 56, 12, 105]
# Sequence 49929 in x
#   Input:  how did you know it was me
#   Output: [47, 33, 2, 37, 9, 15, 10]
# Sequence 49930 in x
#   Input:  how did you make this soup
#   Output: [47, 33, 2, 154, 12, 585]
# Sequence 49931 in x
#   Input:  how do i get to the police
#   Output: [47, 11, 1, 56, 7, 6, 737]
# Sequence 49932 in x
#   Input:  how do i get to your house
#   Output: [47, 11, 1, 56, 7, 21, 149]
# Sequence 49933 in x
#   Input:  how do i get to your house
#   Output: [47, 11, 1, 56, 7, 21, 149]
# Sequence 49934 in x
#   Input:  how do i get to your house
#   Output: [47, 11, 1, 56, 7, 21, 149]
# Sequence 49935 in x
#   Input:  how do you read this kanji
#   Output: [47, 11, 2, 185, 12, 3238]
# Sequence 49936 in x
#   Input:  how do you spell that word
#   Output: [47, 11, 2, 2880, 19, 431]
# Sequence 49937 in x
#   Input:  how do you spell that word
#   Output: [47, 11, 2, 2880, 19, 431]
# Sequence 49938 in x
#   Input:  how do you tell them apart
#   Output: [47, 11, 2, 108, 128, 1724]
# Sequence 49939 in x
#   Input:  how do you tell them apart
#   Output: [47, 11, 2, 108, 128, 1724]
# Sequence 49940 in x
#   Input:  how do you use this camera
#   Output: [47, 11, 2, 257, 12, 507]
# Sequence 49941 in x
#   Input:  how does tom feel about it
#   Output: [47, 117, 3, 142, 90, 9]
# Sequence 49942 in x
#   Input:  how heavy is your suitcase
#   Output: [47, 1257, 4, 21, 1398]
# Sequence 49943 in x
#   Input:  how long are you going for
#   Output: [47, 198, 16, 2, 92, 35]
# Sequence 49944 in x
#   Input:  how long did tom work here
#   Output: [47, 198, 33, 3, 94, 38]
# Sequence 49945 in x
#   Input:  how long did tom work here
#   Output: [47, 198, 33, 3, 94, 38]
# Sequence 49946 in x
#   Input:  how long do i have to stay
#   Output: [47, 198, 11, 1, 17, 7, 130]
# Sequence 49947 in x
#   Input:  how long do i have to wait
#   Output: [47, 198, 11, 1, 17, 7, 155]
# Sequence 49948 in x
#   Input:  how long do i have to wait
#   Output: [47, 198, 11, 1, 17, 7, 155]
# Sequence 49949 in x
#   Input:  how long does a bear sleep
#   Output: [47, 198, 117, 5, 867, 245]
# Sequence 49950 in x
#   Input:  how long has she been sick
#   Output: [47, 198, 45, 22, 131, 306]
# Sequence 49951 in x
#   Input:  how long is the nile river
#   Output: [47, 198, 4, 6, 6936, 878]
# Sequence 49952 in x
#   Input:  how lucky to meet you here
#   Output: [47, 456, 7, 346, 2, 38]
# Sequence 49953 in x
#   Input:  how many are in your party
#   Output: [47, 248, 16, 24, 21, 653]
# Sequence 49954 in x
#   Input:  how many books do you have
#   Output: [47, 248, 297, 11, 2, 17]
# Sequence 49955 in x
#   Input:  how many books do you have
#   Output: [47, 248, 297, 11, 2, 17]
# Sequence 49956 in x
#   Input:  how many dolls do you have
#   Output: [47, 248, 6937, 11, 2, 17]
# Sequence 49957 in x
#   Input:  how many guards were there
#   Output: [47, 248, 3355, 43, 55]
# Sequence 49958 in x
#   Input:  how many pies did you bake
#   Output: [47, 248, 2774, 33, 2, 3077]
# Sequence 49959 in x
#   Input:  how many players are there
#   Output: [47, 248, 2474, 16, 55]
# Sequence 49960 in x
#   Input:  how many rooms do you have
#   Output: [47, 248, 2129, 11, 2, 17]
# Sequence 49961 in x
#   Input:  how many rooms do you have
#   Output: [47, 248, 2129, 11, 2, 17]
# Sequence 49962 in x
#   Input:  how many rooms do you have
#   Output: [47, 248, 2129, 11, 2, 17]
# Sequence 49963 in x
#   Input:  how many windows are there
#   Output: [47, 248, 1215, 16, 55]
# Sequence 49964 in x
#   Input:  how much money did you win
#   Output: [47, 119, 105, 33, 2, 402]
# Sequence 49965 in x
#   Input:  how much money do you have
#   Output: [47, 119, 105, 11, 2, 17]
# Sequence 49966 in x
#   Input:  how much money do you want
#   Output: [47, 119, 105, 11, 2, 31]
# Sequence 49967 in x
#   Input:  how much money do you want
#   Output: [47, 119, 105, 11, 2, 31]
# Sequence 49968 in x
#   Input:  how much money do you want
#   Output: [47, 119, 105, 11, 2, 31]
# Sequence 49969 in x
#   Input:  how much money do you want
#   Output: [47, 119, 105, 11, 2, 31]
# Sequence 49970 in x
#   Input:  how much water do you have
#   Output: [47, 119, 272, 11, 2, 17]
# Sequence 49971 in x
#   Input:  how often do you go abroad
#   Output: [47, 310, 11, 2, 32, 1152]
# Sequence 49972 in x
#   Input:  how often does that happen
#   Output: [47, 310, 117, 19, 305]
# Sequence 49973 in x
#   Input:  how old is your oldest son
#   Output: [47, 147, 4, 21, 2580, 379]
# Sequence 49974 in x
#   Input:  how was i supposed to know
#   Output: [47, 15, 1, 2891, 7, 37]
# Sequence 49975 in x
#   Input:  how was i supposed to know
#   Output: [47, 15, 1, 2891, 7, 37]
# Sequence 49976 in x
#   Input:  i added a room to my house
#   Output: [1, 3574, 5, 146, 7, 13, 149]
# Sequence 49977 in x
#   Input:  i advised him not to drive
#   Output: [1, 2501, 42, 27, 7, 337]
# Sequence 49978 in x
#   Input:  i already knew the outcome
#   Output: [1, 218, 228, 6, 4131]
# Sequence 49979 in x
#   Input:  i already know who you are
#   Output: [1, 218, 37, 72, 2, 16]
# Sequence 49980 in x
#   Input:  i always play by the rules
#   Output: [1, 177, 169, 136, 6, 525]
# Sequence 49981 in x
#   Input:  i am a big fan of the arts
#   Output: [1, 66, 5, 173, 2065, 29, 6, 6938]
# Sequence 49982 in x
#   Input:  i am an optimist by nature
#   Output: [1, 66, 70, 3674, 136, 1507]
# Sequence 49983 in x
#   Input:  i am at home every evening
#   Output: [1, 66, 46, 89, 288, 1462]
# Sequence 49984 in x
#   Input:  i am calculating my salary
#   Output: [1, 66, 6939, 13, 1567]
# Sequence 49985 in x
#   Input:  i am completely against it
#   Output: [1, 66, 833, 1036, 9]
# Sequence 49986 in x
#   Input:  i am eightyfive years old
#   Output: [1, 66, 6940, 671, 147]
# Sequence 49987 in x
#   Input:  i am going down the stairs
#   Output: [1, 66, 92, 123, 6, 1261]
# Sequence 49988 in x
#   Input:  i am happy to see you here
#   Output: [1, 66, 109, 7, 63, 2, 38]
# Sequence 49989 in x
#   Input:  i am in no mood for joking
#   Output: [1, 66, 24, 62, 1220, 35, 684]
# Sequence 49990 in x
#   Input:  i am interested in english
#   Output: [1, 66, 1154, 24, 328]
# Sequence 49991 in x
#   Input:  i am just going for a walk
#   Output: [1, 66, 71, 92, 35, 5, 308]
# Sequence 49992 in x
#   Input:  i am never free on sundays
#   Output: [1, 66, 95, 349, 34, 2062]
# Sequence 49993 in x
#   Input:  i am not happy with my job
#   Output: [1, 66, 27, 109, 57, 13, 141]
# Sequence 49994 in x
#   Input:  i am reading short stories
#   Output: [1, 66, 405, 473, 1729]
# Sequence 49995 in x
#   Input:  i am smoking a cuban cigar
#   Output: [1, 66, 571, 5, 6941, 2704]
# Sequence 49996 in x
#   Input:  i am tired of hearing that
#   Output: [1, 66, 207, 29, 2458, 19]
# Sequence 49997 in x
#   Input:  i am up to my neck in work
#   Output: [1, 66, 48, 7, 13, 1873, 24, 94]
# Sequence 49998 in x
#   Input:  i am waiting for my driver
#   Output: [1, 66, 406, 35, 13, 968]
# Sequence 49999 in x
#   Input:  i appreciate all your help
#   Output: [1, 940, 52, 21, 68]
# Sequence 50000 in x
#   Input:  i appreciate your interest
#   Output: [1, 940, 21, 2596]

# %%
#Tokenizer aplicado a la columna esp (español)
esp_tokenized, esp_tokenizer = utils.tokenization(data_eng_spa_processed[:, 1])
esp_vocab_size = len(esp_tokenizer.word_index) + 1
esp_length = 8
print('Spanish Vocabulary Size: {}'.format(esp_vocab_size))
# Out:
# Spanish Vocabulary Size: 14196

# %%
print(esp_tokenizer.word_counts)
# Out:
# al', 2), ('sillas', 6), ('rapidísimo', 1), ('búsqueda', 3), ('direcciones', 1), ('asistió', 2), ('vengó', 2), ('gracia', 4), ('apostó', 3), ('abrochó', 1), ('razonar', 1), ('aseguró', 1), ('agachaba', 1), ('sugeriste', 1), ('investigó', 1), ('destacado', 1), ('necesitó', 1), ('treintas', 1), ('sucesor', 1), ('aparenta', 1), ('ocupa', 2), ('esteroides', 2), ('alistó', 2), ('llenó', 1), ('espacios', 1), ('concedió', 1), ('desvío', 1), ('británico', 1), ('admirador', 2), ('temperamento', 2), ('rendido', 1), ('regañina', 1), ('acceso', 2), ('maritales', 1), ('cantado', 3), ('heredó', 1), ('exesposo', 1), ('yerno', 1), ('compulsivo', 3), ('convicto', 1), ('amistosa', 1), ('imprudente', 2), ('desconocido', 2), ('parpadeando', 1), ('masticando', 2), ('cortando', 1), ('lamentarlo', 1), ('recostado', 1), ('rival', 1), ('porche', 1), ('podando', 1), ('firmando', 1), ('cabro', 1), ('encenagado', 1), ('conversando', 1), ('patadas', 1), ('tacho', 1), ('decoroso', 1), ('necesitado', 2), ('movimiento', 1), ('batuta', 1), ('chatarra', 2), ('deambulaba', 1), ('remoto', 1), ('planeó', 1), ('fingía', 2), ('disfraz', 1), ('refregó', 1), ('lechuga', 3), ('desplomó', 1), ('enojarse', 1), ('freno', 3), ('disminuya', 1), ('esperara', 2), ('sorbito', 1), ('brandi', 1), ('rescatar', 2), ('pedigüeño', 1), ('exigente', 1), ('dirigió', 1), ('podio', 1), ('probarse', 1), ('comandante', 1), ('tanques', 1), ('enviado', 1), ('irak', 1), ('mero', 1), ('apuñalado', 1), ('campeonato', 1), ('dejaba', 1), ('erróneas', 1), ('compañías', 1), ('máquinas', 1), ('caminá', 1), ('lavate', 1), ('mudaremos', 1), ('escalamos', 1), ('empinada', 1), ('conducimos', 1), ('leve', 1), ('disneylandia', 1), ('problemilla', 1), ('intereses', 1), ('stock', 1), ('existencias', 1), ('gastado', 1), ('solucionarlo', 1), ('positivos', 1), ('importamos', 1), ('reunimos', 1), ('recomenzar', 1), ('ordenamos', 1), ('reposamos', 1), ('propensos', 1), ('creíamos', 1), ('sacamos', 1), ('convencerle', 1), ('tratamos', 1), ('atrapar', 2), ('cases', 2), ('peli', 1), ('descansaremos', 1), ('vendremos', 1), ('visitarte', 2), ('tomaremos', 1), ('emplearemos', 1), ('prácticamente', 1), ('añoramos', 1), ('¡bienvenido', 1), ('mas', 1), ('arcoíris', 1), ('declaración', 1), ('celebras', 1), ('celebrando', 4), ('celebráis', 1), ('celebra', 1), ('celebran', 1), ('buscás', 1), ('esperan', 2), ('miras', 2), ('soñaste', 1), ('planeas', 2), ('opinas', 1), ('usas', 2), ('buscas', 1), ('urss', 1), ('aparato', 1), ('cartel', 1), ('anterior', 1), ('objeto', 1), ('sospechar', 1), ('disfrutas', 1), ('despiertas', 1), ('usarás', 1), ('escampó', 1), ('intermedio', 1), ('dirigen', 1), ('venían', 1), ('solicitar', 1), ('correos', 4), ('patito', 1), ('elegirá', 1), ('escogerá', 1), ('vecinas', 1), ('dividió', 1), ('átomo', 1), ('combustible', 4), ('postor', 1), ('interrumpió', 1), ('comprasteis', 1), ('enfadaste', 1), ('abriste', 2), ('informaste', 1), ('veinticinco', 1), ('centavos', 1), ('cogemos', 1), ('entendéis', 1), ('creerte', 1), ('¿será', 1), ('¿saldrás', 1), ('enseñarás', 2), ('moriríamos', 1), ('dejarías', 1), ('250', 1), ('fermente', 1), ('pedirle', 3), ('¡puede', 1), ('cogerte', 1), ('utilizar', 2), ('contarme', 1), ('sobornar', 1), ('juez', 1), ('escaparte', 1), ('respondas', 1), ('escuchas', 1), ('revelaste', 1), ('recibes', 2), ('consigues', 1), ('regular', 1), ('decisiones', 2), ('alegraste', 1), ('habérsete', 1), ('perdérselo', 2), ('perderla', 1), ('necesitabas', 1), ('ejercitarte', 1), ('derrotarás', 1), ('venceréis', 1), ('arrepentirás', 1), ('oponente', 1), ('engañando', 1), ('especialito', 1), ('tiquismiquis', 1), ('arruinas', 1), ('atmósfera', 1), ('recia', 1), ('comprará', 1), ('espléndido', 1), ('—vamos', 1), ('—me', 1), ('iluminaba', 1), ('cocodrilo', 1), ('indicación', 1), ('añade', 1), ('daña', 1), ('autobuses', 1), ('engañan', 1), ('¿vais', 1), ('excepción', 3), ('asegúrate', 1), ('gallinas', 1), ('negras', 1), ('peleas', 2), ('limítrofes', 1), ('comunes', 1), ('bourbon', 1), ('búlgaro', 1), ( ...

# %%
for sample_i, (sent, token_sent) in enumerate(zip(data_eng_spa_processed[:,1], esp_tokenized)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(sent))
    print('  Output: {}'.format(token_sent))
# Out:
# , 1516, 7, 126]
# Sequence 49787 in x
#   Input:  él se quedó aquí un rato
#   Output: [11, 13, 515, 30, 8, 891]
# Sequence 49788 in x
#   Input:  él todavía tiene mucho que aprender
#   Output: [11, 130, 37, 80, 9, 684]
# Sequence 49789 in x
#   Input:  se paró ahí por un rato
#   Output: [13, 1149, 132, 19, 8, 891]
# Sequence 49790 in x
#   Input:  él se detuvo para hablarles
#   Output: [11, 13, 2026, 51, 14152]
# Sequence 49791 in x
#   Input:  él se paró a hablar con ellos
#   Output: [11, 13, 1149, 4, 118, 32, 53]
# Sequence 49792 in x
#   Input:  él también estudia chino
#   Output: [11, 175, 1309, 1249]
# Sequence 49793 in x
#   Input:  me dio las gracias por el regalo
#   Output: [10, 201, 26, 224, 19, 7, 704]
# Sequence 49794 in x
#   Input:  me agradeció por el regalo
#   Output: [10, 4723, 19, 7, 704]
# Sequence 49795 in x
#   Input:  él me dio todos los detalles
#   Output: [11, 10, 201, 58, 25, 1698]
# Sequence 49796 in x
#   Input:  él me dijo que me lavara la cara
#   Output: [11, 10, 134, 9, 10, 14153, 6, 434]
# Sequence 49797 in x
#   Input:  él me dijo cuándo decir sí
#   Output: [11, 10, 134, 1851, 207, 257]
# Sequence 49798 in x
#   Input:  él me tocó en la mejilla
#   Output: [11, 10, 1970, 15, 6, 7634]
# Sequence 49799 in x
#   Input:  se cayó por las escaleras
#   Output: [13, 536, 19, 26, 1009]
# Sequence 49800 in x
#   Input:  él se puso pálido al oír la noticia
#   Output: [11, 13, 306, 1663, 47, 1272, 6, 1214]
# Sequence 49801 in x
#   Input:  él apareció una hora más tarde
#   Output: [11, 1435, 16, 171, 40, 131]
# Sequence 49802 in x
#   Input:  él visitó kioto el año pasado
#   Output: [11, 2329, 2170, 7, 566, 373]
# Sequence 49803 in x
#   Input:  él se ofreció voluntario para ayudarla
#   Output: [11, 13, 2177, 3686, 51, 2853]
# Sequence 49804 in x
#   Input:  él lo esperó hasta las diez
#   Output: [11, 14, 2027, 241, 26, 501]
# Sequence 49805 in x
#   Input:  anduvo todo el camino hasta casa
#   Output: [7434, 57, 7, 343, 241, 48]
# Sequence 49806 in x
#   Input:  él quiere que vaya con él
#   Output: [11, 107, 9, 582, 32, 11]
# Sequence 49807 in x
#   Input:  él me alertó del peligro
#   Output: [11, 10, 14154, 115, 555]
# Sequence 49808 in x
#   Input:  él era un dios para su gente
#   Output: [11, 69, 8, 696, 51, 27, 326]
# Sequence 49809 in x
#   Input:  casi le atropelló un coche
#   Output: [196, 22, 3659, 8, 126]
# Sequence 49810 in x
#   Input:  él estaba enojado con su esposa
#   Output: [11, 42, 635, 32, 27, 449]
# Sequence 49811 in x
#   Input:  él fue arrestado por homicidio
#   Output: [11, 46, 3227, 19, 7616]
# Sequence 49812 in x
#   Input:  él fue atacado por un tiburón
#   Output: [11, 46, 14155, 19, 8, 7638]
# Sequence 49813 in x
#   Input:  le atacó un tiburón
#   Output: [22, 3952, 8, 7638]
# Sequence 49814 in x
#   Input:  él fue consciente del peligro
#   Output: [11, 46, 1308, 115, 555]
# Sequence 49815 in x
#   Input:  él fue bautizado católico
#   Output: [11, 46, 14156, 14157]
# Sequence 49816 in x
#   Input:  él nació en suiza
#   Output: [11, 1036, 15, 14158]
# Sequence 49817 in x
#   Input:  estaba atado de pies y manos
#   Output: [42, 14159, 5, 1485, 75, 363]
# Sequence 49818 in x
#   Input:  cayó en una emboscada
#   Output: [536, 15, 16, 3859]
# Sequence 49819 in x
#   Input:  se notaba que estaba avergonzado
#   Output: [13, 14160, 9, 42, 1509]
# Sequence 49820 in x
#   Input:  era evidente que estaba avergonzado
#   Output: [69, 5834, 9, 42, 1509]
# Sequence 49821 in x
#   Input:  estaba totalmente agotado
#   Output: [42, 850, 1176]
# Sequence 49822 in x
#   Input:  estaba agotadísimo
#   Output: [42, 14161]
# Sequence 49823 in x
#   Input:  estaba cruzando la calle
#   Output: [42, 5289, 6, 950]
# Sequence 49824 in x
#   Input:  estaba desesperado por escapar
#   Output: [42, 3195, 19, 1114]
# Sequence 49825 in x
#   Input:  él fue elegido alcalde de nuevo
#   Output: [11, 46, 2654, 1804, 5, 127]
# Sequence 49826 in x
#   Input:  lo mataron con una espada
#   Output: [14, 3480, 32, 16, 3309]
# Sequence 49827 in x
#   Input:  le pagaron 10000 dólares
#   Output: [22, 2494, 6941, 839]
# Sequence 49828 in x
#   Input:  él era popular entre sus electores
#   Output: [11, 69, 2256, 1013, 145, 14162]
# Sequence 49829 in x
#   Input:  él estaba leyendo el periódico
#   Output: [11, 42, 585, 7, 1375]
# Sequence 49830 in x
#   Input:  lo atropellaron y falleció
#   Output: [14, 14163, 75, 4021]
# Sequence 49831 in x
#   Input:  él buscaba la reelección
#   Output: [11, 3009, 6, 14164]
# Sequence 49832 in x
#   Input:  él fue sentenciado a prisión
#   Output: [11, 46, 7610, 4, 1590]
# Sequence 49833 in x
#   Input:  a él le hirió una bala
#   Output: [4, 11, 22, 3473, 16, 3498]
# Sequence 49834 in x
#   Input:  él fue herido por una bala
#   Output: [11, 46, 715, 19, 16, 3498]
# Sequence 49835 in x
#   Input:  él fue herido en la cabeza
#   Output: [11, 46, 715, 15, 6, 409]
# Sequence 49836 in x
#   Input:  él pesa cerca de 300 libras
#   Output: [11, 4217, 308, 5, 2668, 14165]
# Sequence 49837 in x
#   Input:  él fue ayer a tokio
#   Output: [11, 46, 238, 4, 918]
# Sequence 49838 in x
#   Input:  él volverá en una hora
#   Output: [11, 1457, 15, 16, 171]
# Sequence 49839 in x
#   Input:  él estará aquí en cualquier momento
#   Output: [11, 664, 30, 15, 609, 295]
# Sequence 49840 in x
#   Input:  él estará arruinado de por vida
#   Output: [11, 664, 3081, 5, 19, 181]
# Sequence 49841 in x
#   Input:  él estará esperándote
#   Output: [11, 664, 14166]
# Sequence 49842 in x
#   Input:  él te estará esperando
#   Output: [11, 20, 664, 365]
# Sequence 49843 in x
#   Input:  él se pondrá bien muy pronto
#   Output: [11, 13, 4133, 52, 28, 211]
# Sequence 49844 in x
#   Input:  el será un buen doctor
#   Output: [7, 318, 8, 124, 606]
# Sequence 49845 in x
#   Input:  él pagará por todo
#   Output: [11, 3590, 19, 57]
# Sequence 49846 in x
#   Input:  ganó el premio la semana pasada
#   Output: [623, 7, 1221, 6, 246, 920]
# Sequence 49847 in x
#   Input:  él trabajó con más entusiasmo que nunca
#   Output: [11, 1243, 32, 40, 7432, 9, 86]
# Sequence 49848 in x
#   Input:  él trabaja ocho horas al día
#   Output: [11, 396, 1312, 946, 47, 142]
# Sequence 49849 in x
#   Input:  él trabaja en el laboratorio
#   Output: [11, 396, 15, 7, 6533]
# Sequence 49850 in x
#   Input:  él tendría que rendirse
#   Output: [11, 7323, 9, 3532]
# Sequence 49851 in x
#   Input:  él es un ciudadano escrupuloso con la ley
#   Output: [11, 3, 8, 2120, 14167, 32, 6, 976]
# Sequence 49852 in x
#   Input:  él es un ciudadano respetuoso de la ley
#   Output: [11, 3, 8, 2120, 3663, 5, 6, 976]
# Sequence 49853 in x
#   Input:  él es un hombre en el que puedes confiar
#   Output: [11, 3, 8, 143, 15, 7, 9, 108, 621]
# Sequence 49854 in x
#   Input:  él es profesor y yo también
#   Output: [11, 3, 422, 75, 23, 175]
# Sequence 49855 in x
#   Input:  él es una persona muy egoísta
#   Output: [11, 3, 16, 290, 28, 1890]
# Sequence 49856 in x
#   Input:  él es adicto a la comida chatarra
#   Output: [11, 3, 2535, 4, 6, 193, 7521]
# Sequence 49857 in x
#   Input:  él siempre llega tarde a clases
#   Output: [11, 123, 832, 131, 4, 869]
# Sequence 49858 in x
#   Input:  él siempre está leyendo cómics
#   Output: [11, 123, 12, 585, 14168]
# Sequence 49859 in x
#   Input:  él siempre tiene problemas de dinero
#   Output: [11, 123, 37, 626, 5, 101]
# Sequence 49860 in x
#   Input:  él siempre está corto de plata
#   Output: [11, 123, 12, 1189, 5, 1685]
# Sequence 49861 in x
#   Input:  siempre anda corto de dinero
#   Output: [123, 1127, 1189, 5, 101]
# Sequence 49862 in x
#   Input:  él definitivamente no vendrá
#   Output: [11, 3024, 2, 768]
# Sequence 49863 in x
#   Input:  está cavando su propia tumba
#   Output: [12, 2452, 27, 1714, 3876]
# Sequence 49864 in x
#   Input:  él está cavando su propia tumba
#   Output: [11, 12, 2452, 27, 1714, 3876]
# Sequence 49865 in x
#   Input:  él está haciendo algo allí
#   Output: [11, 12, 218, 78, 125]
# Sequence 49866 in x
#   Input:  está deseando hablar contigo
#   Output: [12, 2367, 118, 264]
# Sequence 49867 in x
#   Input:  él se va de regreso a américa
#   Output: [11, 13, 111, 5, 3128, 4, 1523]
# Sequence 49868 in x
#   Input:  él es perfecto en todo
#   Output: [11, 3, 601, 15, 57]
# Sequence 49869 in x
#   Input:  es más bien rico que pobre
#   Output: [3, 40, 52, 411, 9, 1082]
# Sequence 49870 in x
#   Input:  él es más inteligente que ellos
#   Output: [11, 3, 40, 487, 9, 53]
# Sequence 49871 in x
#   Input:  él es estúpido e irracional
#   Output: [11, 3, 473, 2190, 6928]
# Sequence 49872 in x
#   Input:  él es el capitán de un equipo
#   Output: [11, 3, 7, 2970, 5, 8, 564]
# Sequence 49873 in x
#   Input:  es el quinto de la fila
#   Output: [3, 7, 4235, 5, 6, 4966]
# Sequence 49874 in x
#   Input:  él está escribiendo una larga carta
#   Output: [11, 12, 1025, 16, 1076, 382]
# Sequence 49875 in x
#   Input:  también él visitaría china
#   Output: [175, 11, 14169, 1461]
# Sequence 49876 in x
#   Input:  la ayuda ya está en camino
#   Output: [6, 138, 79, 12, 15, 343]
# Sequence 49877 in x
#   Input:  ayúdame a bajar del coche
#   Output: [1116, 4, 2955, 115, 126]
# Sequence 49878 in x
#   Input:  ayúdeme a salir del coche
#   Output: [3748, 4, 356, 115, 126]
# Sequence 49879 in x
#   Input:  ayúdame a aprender a conducir
#   Output: [1116, 4, 684, 4, 647]
# Sequence 49880 in x
#   Input:  sus libros se venden muy bien
#   Output: [145, 253, 13, 2368, 28, 52]
# Sequence 49881 in x
#   Input:  los ojos de ella se llenaron de lágrimas
#   Output: [25, 284, 5, 18, 13, 5359, 5, 1993]
# Sequence 49882 in x
#   Input:  sus ojos se llenaron de lágrimas
#   Output: [145, 284, 13, 5359, 5, 1993]
# Sequence 49883 in x
#   Input:  su familia se mudó a brasil
#   Output: [27, 338, 13, 3578, 4, 4657]
# Sequence 49884 in x
#   Input:  su pelo está mojado con el sudor
#   Output: [27, 286, 12, 2725, 32, 7, 7559]
# Sequence 49885 in x
#   Input:  su casa está cerca del parque
#   Output: [27, 48, 12, 308, 115, 1285]
# Sequence 49886 in x
#   Input:  su mirada expresaba su alegría
#   Output: [27, 1959, 14170, 27, 2309]
# Sequence 49887 in x
#   Input:  su nombre fue deletreado mal
#   Output: [27, 190, 46, 14171, 161]
# Sequence 49888 in x
#   Input:  deletrearon mal su nombre
#   Output: [14172, 161, 27, 190]
# Sequence 49889 in x
#   Input:  su viejo gato todavía está vivo
#   Output: [27, 362, 208, 130, 12, 364]
# Sequence 49890 in x
#   Input:  su discurso rebosaba de ingenio
#   Output: [27, 1838, 14173, 5, 14174]
# Sequence 49891 in x
#   Input:  su vanidad no tiene límite
#   Output: [27, 14175, 2, 37, 4708]
# Sequence 49892 in x
#   Input:  su casa se halla en la colina
#   Output: [27, 48, 13, 14176, 15, 6, 2389]
# Sequence 49893 in x
#   Input:  aquí hay una foto mía
#   Output: [30, 105, 16, 712, 435]
# Sequence 49894 in x
#   Input:  aquí hay una foto hecha por mi
#   Output: [30, 105, 16, 712, 1695, 19, 17]
# Sequence 49895 in x
#   Input:  aquí tienes mi número de teléfono
#   Output: [30, 92, 17, 648, 5, 266]
# Sequence 49896 in x
#   Input:  che necesito hablar con vos
#   Output: [2375, 83, 118, 32, 447]
# Sequence 49897 in x
#   Input:  su respiración se volvió dificultosa
#   Output: [27, 3315, 13, 423, 14177]
# Sequence 49898 in x
#   Input:  su coche es parecido al mío
#   Output: [27, 126, 3, 7507, 47, 289]
# Sequence 49899 in x
#   Input:  su muerte nos sorprendió a todos
#   Output: [27, 653, 61, 1805, 4, 58]
# Sequence 49900 in x
#   Input:  su esfuerzo dará fruto
#   Output: [27, 1958, 3461, 7596]
# Sequence 49901 in x
#   Input:  sus ojos se llenaron de lágrimas
#   Output: [145, 284, 13, 5359, 5, 1993]
# Sequence 49902 in x
#   Input:  su padre era policía
#   Output: [27, 160, 69, 499]
# Sequence 49903 in x
#   Input:  su novia es japonesa
#   Output: [27, 735, 3, 1417]
# Sequence 49904 in x
#   Input:  su amiga es japonesa
#   Output: [27, 707, 3, 1417]
# Sequence 49905 in x
#   Input:  su broma nos hizo reír a todos
#   Output: [27, 629, 61, 99, 982, 4, 58]
# Sequence 49906 in x
#   Input:  sus discursos son muy largos
#   Output: [145, 14178, 43, 28, 5268]
# Sequence 49907 in x
#   Input:  sus conferencias son muy largas
#   Output: [145, 14179, 43, 28, 1948]
# Sequence 49908 in x
#   Input:  lo que él trata de decir es bien sencillo de comprender
#   Output: [14, 9, 11, 708, 5, 207, 3, 52, 2767, 5, 7586]
# Sequence 49909 in x
#   Input:  su nombre nos resulta familiar
#   Output: [27, 190, 61, 2923, 2924]
# Sequence 49910 in x
#   Input:  su viejo gato todavía está vivo
#   Output: [27, 362, 208, 130, 12, 364]
# Sequence 49911 in x
#   Input:  su profecía se cumplió
#   Output: [27, 3457, 13, 2077]
# Sequence 49912 in x
#   Input:  su hermana se hizo médica
#   Output: [27, 393, 13, 99, 2759]
# Sequence 49913 in x
#   Input:  su hijo tiene ocho años
#   Output: [27, 274, 37, 1312, 226]
# Sequence 49914 in x
#   Input:  su hijo temblaba de terror
#   Output: [27, 274, 7585, 5, 3903]
# Sequence 49915 in x
#   Input:  sus hijos hacen lo que se les antoja
#   Output: [145, 385, 940, 14, 9, 13, 189, 14180]
# Sequence 49916 in x
#   Input:  su técnica era la mejor
#   Output: [27, 7572, 69, 6, 128]
# Sequence 49917 in x
#   Input:  su trabajo es hacer relojes
#   Output: [27, 81, 3, 82, 5689]
# Sequence 49918 in x
#   Input:  holanda es un país pequeño
#   Output: [7566, 3, 8, 1440, 581]
# Sequence 49919 in x
#   Input:  la honestidad no siempre paga
#   Output: [6, 4045, 2, 123, 970]
# Sequence 49920 in x
#   Input:  ¿qué tal si quedamos mañana
#   Output: [35, 301, 209, 1254, 140]
# Sequence 49921 in x
#   Input:  ¿qué te parece si quedamos mañana
#   Output: [35, 20, 116, 209, 1254, 140]
# Sequence 49922 in x
#   Input:  ¿cómo puedo hacerte cambiar de opinión
#   Output: [77, 49, 2681, 1067, 5, 801]
# Sequence 49923 in x
#   Input:  ¿cómo puedo encender el motor
#   Output: [77, 49, 2999, 7, 2108]
# Sequence 49924 in x
#   Input:  ¿cómo es que no apareció
#   Output: [77, 3, 9, 2, 1435]
# Sequence 49925 in x
#   Input:  ¿cómo se filtró el secreto
#   Output: [77, 13, 14181, 7, 419]
# Sequence 49926 in x
#   Input:  ¿cómo te pasó esto
#   Output: [77, 20, 277, 29]
# Sequence 49927 in x
#   Input:  ¿cómo encontraste ese libro
#   Output: [77, 1947, 93, 90]
# Sequence 49928 in x
#   Input:  ¿cómo conseguiste este dinero
#   Output: [77, 7286, 44, 101]
# Sequence 49929 in x
#   Input:  ¿cómo supiste que fui yo
#   Output: [77, 14182, 9, 240, 23]
# Sequence 49930 in x
#   Input:  ¿cómo hiciste esta sopa
#   Output: [77, 401, 55, 577]
# Sequence 49931 in x
#   Input:  ¿cómo se llega a la policía
#   Output: [77, 13, 832, 4, 6, 499]
# Sequence 49932 in x
#   Input:  ¿cómo voy a tu casa
#   Output: [77, 84, 4, 36, 48]
# Sequence 49933 in x
#   Input:  ¿cómo se va a vuestra casa
#   Output: [77, 13, 111, 4, 878, 48]
# Sequence 49934 in x
#   Input:  ¿cómo llego a tu casa
#   Output: [77, 1729, 4, 36, 48]
# Sequence 49935 in x
#   Input:  ¿cómo se lee este kanji
#   Output: [77, 13, 1017, 44, 4949]
# Sequence 49936 in x
#   Input:  ¿cómo se deletrea esa palabra
#   Output: [77, 13, 14183, 112, 476]
# Sequence 49937 in x
#   Input:  ¿cómo se escribe esa palabra
#   Output: [77, 13, 897, 112, 476]
# Sequence 49938 in x
#   Input:  ¿cómo puedes distinguirlos
#   Output: [77, 108, 14184]
# Sequence 49939 in x
#   Input:  ¿cómo podéis distinguirlas
#   Output: [77, 658, 14185]
# Sequence 49940 in x
#   Input:  ¿cómo se usa esta cámara
#   Output: [77, 13, 1083, 55, 484]
# Sequence 49941 in x
#   Input:  ¿cómo se siente tom acerca de eso
#   Output: [77, 13, 845, 1, 558, 5, 24]
# Sequence 49942 in x
#   Input:  ¿cuánto pesa vuestra maleta
#   Output: [270, 4217, 878, 1976]
# Sequence 49943 in x
#   Input:  ¿por cuánto tiempo vas
#   Output: [54, 1530, 97, 292]
# Sequence 49944 in x
#   Input:  ¿cuánto tiempo trabajó tom acá
#   Output: [270, 97, 1243, 1, 372]
# Sequence 49945 in x
#   Input:  ¿cuánto tiempo trabajó aquí tom
#   Output: [270, 97, 1243, 30, 1]
# Sequence 49946 in x
#   Input:  ¿por cuánto me tengo que quedar
#   Output: [54, 1530, 10, 31, 9, 995]
# Sequence 49947 in x
#   Input:  ¿por cuánto tengo que esperar
#   Output: [54, 1530, 31, 9, 359]
# Sequence 49948 in x
#   Input:  ¿cuánto tengo que esperar
#   Output: [270, 31, 9, 359]
# Sequence 49949 in x
#   Input:  ¿cuánto tiempo duerme un oso
#   Output: [270, 97, 1265, 8, 1917]
# Sequence 49950 in x
#   Input:  ¿desde cuanto hace que ella está enferma
#   Output: [7402, 2394, 114, 9, 18, 12, 858]
# Sequence 49951 in x
#   Input:  ¿cuál es la longitud del río nilo
#   Output: [152, 3, 6, 7305, 115, 943, 14186]
# Sequence 49952 in x
#   Input:  qué afortunado de verte aquí
#   Output: [34, 1429, 5, 367, 30]
# Sequence 49953 in x
#   Input:  ¿cuántas personas son
#   Output: [2178, 938, 43]
# Sequence 49954 in x
#   Input:  ¿cuántos libros tienes
#   Output: [506, 253, 92]
# Sequence 49955 in x
#   Input:  ¿cuántos libros tiene usted
#   Output: [506, 253, 37, 95]
# Sequence 49956 in x
#   Input:  ¿cuántas muñecas tienes
#   Output: [2178, 14187, 92]
# Sequence 49957 in x
#   Input:  ¿cuántos guardias había
#   Output: [506, 5123, 327]
# Sequence 49958 in x
#   Input:  ¿cuántos pasteles horneaste
#   Output: [506, 3317, 14188]
# Sequence 49959 in x
#   Input:  ¿cuántos jugadores hay
#   Output: [506, 3500, 105]
# Sequence 49960 in x
#   Input:  ¿cuántas habitaciones tienes
#   Output: [2178, 5343, 92]
# Sequence 49961 in x
#   Input:  ¿cuántas habitaciones tenés
#   Output: [2178, 5343, 532]
# Sequence 49962 in x
#   Input:  ¿cuántos cuartos tenés
#   Output: [506, 14189, 532]
# Sequence 49963 in x
#   Input:  ¿cuántas ventanas hay
#   Output: [2178, 1455, 105]
# Sequence 49964 in x
#   Input:  ¿cuánto dinero ganaste
#   Output: [270, 101, 14190]
# Sequence 49965 in x
#   Input:  ¿cuánto dinero tienes
#   Output: [270, 101, 92]
# Sequence 49966 in x
#   Input:  ¿cuánto dinero quieres
#   Output: [270, 101, 313]
# Sequence 49967 in x
#   Input:  ¿cuánto dinero quiere
#   Output: [270, 101, 107]
# Sequence 49968 in x
#   Input:  ¿cuánto dinero queréis
#   Output: [270, 101, 1926]
# Sequence 49969 in x
#   Input:  ¿cuánto dinero quieren
#   Output: [270, 101, 587]
# Sequence 49970 in x
#   Input:  ¿cuánta agua tienes
#   Output: [2356, 206, 92]
# Sequence 49971 in x
#   Input:  ¿con qué frecuencia vas al extranjero
#   Output: [775, 34, 1133, 292, 47, 1060]
# Sequence 49972 in x
#   Input:  ¿con qué frecuencia pasa eso
#   Output: [775, 34, 1133, 378, 24]
# Sequence 49973 in x
#   Input:  ¿cuántos años tiene tu hijo mayor
#   Output: [506, 226, 37, 36, 274, 643]
# Sequence 49974 in x
#   Input:  ¿cómo se suponía que lo supiera
#   Output: [77, 13, 14191, 9, 14, 4515]
# Sequence 49975 in x
#   Input:  ¿cómo iba a saberlo
#   Output: [77, 709, 4, 1048]
# Sequence 49976 in x
#   Input:  añadí una habitación a mi casa
#   Output: [5672, 16, 184, 4, 17, 48]
# Sequence 49977 in x
#   Input:  le aconsejé que no condujera
#   Output: [22, 14192, 9, 2, 4100]
# Sequence 49978 in x
#   Input:  ya conocía el resultado
#   Output: [79, 1977, 7, 2615]
# Sequence 49979 in x
#   Input:  ya sé quien sos
#   Output: [79, 63, 1269, 183]
# Sequence 49980 in x
#   Input:  siempre juego según las reglas
#   Output: [123, 368, 7576, 26, 702]
# Sequence 49981 in x
#   Input:  soy un gran fanático del arte
#   Output: [45, 8, 269, 5559, 115, 1471]
# Sequence 49982 in x
#   Input:  soy optimista por naturaleza
#   Output: [45, 2511, 19, 2071]
# Sequence 49983 in x
#   Input:  estoy en casa todas las noches
#   Output: [21, 15, 48, 455, 26, 1834]
# Sequence 49984 in x
#   Input:  estoy calculando mi sueldo
#   Output: [21, 14193, 17, 2658]
# Sequence 49985 in x
#   Input:  estoy completamente en contra
#   Output: [21, 711, 15, 1037]
# Sequence 49986 in x
#   Input:  tengo ochenta y cinco años
#   Output: [31, 3975, 75, 541, 226]
# Sequence 49987 in x
#   Input:  voy bajando las escaleras
#   Output: [84, 3954, 26, 1009]
# Sequence 49988 in x
#   Input:  estoy feliz de verte aquí
#   Output: [21, 133, 5, 367, 30]
# Sequence 49989 in x
#   Input:  hoy no ando de humor para bromas
#   Output: [94, 2, 2121, 5, 1147, 51, 2960]
# Sequence 49990 in x
#   Input:  estoy interesado en el inglés
#   Output: [21, 2510, 15, 7, 278]
# Sequence 49991 in x
#   Input:  sólo voy a dar un paseo
#   Output: [229, 84, 4, 469, 8, 1493]
# Sequence 49992 in x
#   Input:  nunca estoy libre los domingos
#   Output: [86, 21, 346, 25, 1687]
# Sequence 49993 in x
#   Input:  no estoy contento con mi trabajo
#   Output: [2, 21, 695, 32, 17, 81]
# Sequence 49994 in x
#   Input:  estoy leyendo cuentos cortos
#   Output: [21, 585, 14194, 3985]
# Sequence 49995 in x
#   Input:  estoy fumando un cigarro cubano
#   Output: [21, 3757, 8, 2592, 14195]
# Sequence 49996 in x
#   Input:  estoy cansada de oír eso
#   Output: [21, 926, 5, 1272, 24]
# Sequence 49997 in x
#   Input:  estoy hasta el cuello de trabajo
#   Output: [21, 241, 7, 2477, 5, 81]
# Sequence 49998 in x
#   Input:  estoy esperando a mi chofer
#   Output: [21, 365, 4, 17, 3916]
# Sequence 49999 in x
#   Input:  aprecio toda tu ayuda
#   Output: [1538, 281, 36, 138]
# Sequence 50000 in x
#   Input:  agradezco tu interés
#   Output: [2217, 36, 5239]

# %% [markdown]
# #### _Padding_

# %%
def pad(x, length=None):
    """
    Pad x
    :param x: List of sequences.
    :param length: Length to pad the sequence to.  If None, use length of longest sequence in x.
    :return: Padded numpy array of sequences
    """
    # TODO: Implement
    return pad_sequences(x, maxlen=length, padding='post')

# %%
test_eng_pad = pad(eng_tokenized)

for sample_i, (token_sent, pad_sent) in enumerate(zip(eng_tokenized, test_eng_pad)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(np.array(token_sent)))
    print('  Output: {}'.format(pad_sent))
# Out:
# 75  136    5 4572]
#   Output: [   8   15 1775  136    5 4572    0    0]
# Sequence 49813 in x
#   Input:  [   8   15 1775  136    5 4572]
#   Output: [   8   15 1775  136    5 4572    0    0]
# Sequence 49814 in x
#   Input:  [  8  15 909  29   6 604]
#   Output: [  8  15 909  29   6 604   0   0]
# Sequence 49815 in x
#   Input:  [   8   15 4189    5 2643]
#   Output: [   8   15 4189    5 2643    0    0    0]
# Sequence 49816 in x
#   Input:  [   8   15  548   24 6922]
#   Output: [   8   15  548   24 6922    0    0    0]
# Sequence 49817 in x
#   Input:  [   8   15 2849  367  106  989]
#   Output: [   8   15 2849  367  106  989    0    0]
# Sequence 49818 in x
#   Input:  [   8   15  443   24   70 3744]
#   Output: [   8   15  443   24   70 3744    0    0]
# Sequence 49819 in x
#   Input:  [   8   15 1024 1163]
#   Output: [   8   15 1024 1163    0    0    0    0]
# Sequence 49820 in x
#   Input:  [   8   15 1024 1163]
#   Output: [   8   15 1024 1163    0    0    0    0]
# Sequence 49821 in x
#   Input:  [  8  15 833 841  67]
#   Output: [  8  15 833 841  67   0   0   0]
# Sequence 49822 in x
#   Input:  [  8  15 833 841  67]
#   Output: [  8  15 833 841  67   0   0   0]
# Sequence 49823 in x
#   Input:  [   8   15 4358    6  965]
#   Output: [   8   15 4358    6  965    0    0    0]
# Sequence 49824 in x
#   Input:  [   8   15 1871    7  882]
#   Output: [   8   15 1871    7  882    0    0    0]
# Sequence 49825 in x
#   Input:  [   8   15 1981 1435  144]
#   Output: [   8   15 1981 1435  144    0    0    0]
# Sequence 49826 in x
#   Input:  [   8   15  608   57    5 2633]
#   Output: [   8   15  608   57    5 2633    0    0]
# Sequence 49827 in x
#   Input:  [   8   15  537 4156  970]
#   Output: [   8   15  537 4156  970    0    0    0]
# Sequence 49828 in x
#   Input:  [   8   15 1612   57 6923]
#   Output: [   8   15 1612   57 6923    0    0    0]
# Sequence 49829 in x
#   Input:  [   8   15  405    5 1224]
#   Output: [   8   15  405    5 1224    0    0    0]
# Sequence 49830 in x
#   Input:  [  8  15 352 219 106 608]
#   Output: [  8  15 352 219 106 608   0   0]
# Sequence 49831 in x
#   Input:  [   8   15 4446 4520]
#   Output: [   8   15 4446 4520    0    0    0    0]
# Sequence 49832 in x
#   Input:  [   8   15 3501    7 1102]
#   Output: [   8   15 3501    7 1102    0    0    0]
# Sequence 49833 in x
#   Input:  [   8   15 1631  136    5 2304]
#   Output: [   8   15 1631  136    5 2304    0    0]
# Sequence 49834 in x
#   Input:  [   8   15 1631  136    5 2304]
#   Output: [   8   15 1631  136    5 2304    0    0]
# Sequence 49835 in x
#   Input:  [   8   15 1631   24    6  733]
#   Output: [   8   15 1631   24    6  733    0    0]
# Sequence 49836 in x
#   Input:  [   8 6924   90 1702 4568]
#   Output: [   8 6924   90 1702 4568    0    0    0]
# Sequence 49837 in x
#   Input:  [  8 127   7 824 282]
#   Output: [  8 127   7 824 282   0   0   0]
# Sequence 49838 in x
#   Input:  [  8  64  30  93  24  70 703]
#   Output: [  8  64  30  93  24  70 703   0]
# Sequence 49839 in x
#   Input:  [  8  64  30  38 187 606]
#   Output: [  8  64  30  38 187 606   0   0]
# Sequence 49840 in x
#   Input:  [   8   64   30 1312   35  234]
#   Output: [   8   64   30 1312   35  234    0    0]
# Sequence 49841 in x
#   Input:  [  8  64  30 406  35   2]
#   Output: [  8  64  30 406  35   2   0   0]
# Sequence 49842 in x
#   Input:  [  8  64  30 406  35   2]
#   Output: [  8  64  30 406  35   2   0   0]
# Sequence 49843 in x
#   Input:  [  8  64  56  84  40 268]
#   Output: [  8  64  56  84  40 268   0   0]
# Sequence 49844 in x
#   Input:  [  8  64 154   5  59 317]
#   Output: [  8  64 154   5  59 317   0   0]
# Sequence 49845 in x
#   Input:  [  8  64 203  35 193]
#   Output: [  8  64 203  35 193   0   0   0]
# Sequence 49846 in x
#   Input:  [   8  420    6 1319  208  330]
#   Output: [   8  420    6 1319  208  330    0    0]
# Sequence 49847 in x
#   Input:  [   8  577 1335  239  392]
#   Output: [   8  577 1335  239  392    0    0    0]
# Sequence 49848 in x
#   Input:  [   8  375 1295 1001    5  150]
#   Output: [   8  375 1295 1001    5  150    0    0]
# Sequence 49849 in x
#   Input:  [   8  375   24    6 6925]
#   Output: [   8  375   24    6 6925    0    0    0]
# Sequence 49850 in x
#   Input:  [   8  178   17    7 2041]
#   Output: [   8  178   17    7 2041    0    0    0]
# Sequence 49851 in x
#   Input:  [  79    5 4573 1444]
#   Output: [  79    5 4573 1444    0    0    0    0]
# Sequence 49852 in x
#   Input:  [  79    5 4573 1444]
#   Output: [  79    5 4573 1444    0    0    0    0]
# Sequence 49853 in x
#   Input:  [  79    5  165    2   25 1939   34]
#   Output: [  79    5  165    2   25 1939   34    0]
# Sequence 49854 in x
#   Input:  [ 79   5 335 106  82  66   1]
#   Output: [ 79   5 335 106  82  66   1   0]
# Sequence 49855 in x
#   Input:  [  79    5   40 1485  348]
#   Output: [  79    5   40 1485  348    0    0    0]
# Sequence 49856 in x
#   Input:  [  79 3412    7 3493  254]
#   Output: [  79 3412    7 3493  254    0    0    0]
# Sequence 49857 in x
#   Input:  [  79  177  180   35 1000]
#   Output: [  79  177  180   35 1000    0    0    0]
# Sequence 49858 in x
#   Input:  [  79  177  405 6926]
#   Output: [  79  177  405 6926    0    0    0    0]
# Sequence 49859 in x
#   Input:  [ 79 177 473  29 105]
#   Output: [ 79 177 473  29 105   0   0   0]
# Sequence 49860 in x
#   Input:  [ 79 177 473  29 105]
#   Output: [ 79 177 473  29 105   0   0   0]
# Sequence 49861 in x
#   Input:  [ 79 177 473  29 105]
#   Output: [ 79 177 473  29 105   0   0   0]
# Sequence 49862 in x
#   Input:  [  79 2002   27  266]
#   Output: [  79 2002   27  266    0    0    0    0]
# Sequence 49863 in x
#   Input:  [  79 1604   41  342 2118]
#   Output: [  79 1604   41  342 2118    0    0    0]
# Sequence 49864 in x
#   Input:  [  79 1604   41  342 2118]
#   Output: [  79 1604   41  342 2118    0    0    0]
# Sequence 49865 in x
#   Input:  [ 79 221 152  55]
#   Output: [ 79 221 152  55   0   0   0   0]
# Sequence 49866 in x
#   Input:  [  79 2211    7  135    7    2]
#   Output: [  79 2211    7  135    7    2    0    0]
# Sequence 49867 in x
#   Input:  [ 79  92  93   7 915]
#   Output: [ 79  92  93   7 915   0   0   0]
# Sequence 49868 in x
#   Input:  [ 79 509  46 193]
#   Output: [ 79 509  46 193   0   0   0   0]
# Sequence 49869 in x
#   Input:  [ 79 345 674 239 696]
#   Output: [ 79 345 674 239 696   0   0   0]
# Sequence 49870 in x
#   Input:  [  79 1820  239   36   16]
#   Output: [  79 1820  239   36   16    0    0    0]
# Sequence 49871 in x
#   Input:  [  79  341  106 6927]
#   Output: [  79  341  106 6927    0    0    0    0]
# Sequence 49872 in x
#   Input:  [  79    6 2168   29    5  587]
#   Output: [  79    6 2168   29    5  587    0    0]
# Sequence 49873 in x
#   Input:  [  79    6 4528  165   24  926]
#   Output: [  79    6 4528  165   24  926    0    0]
# Sequence 49874 in x
#   Input:  [ 79 628   5 198 452]
#   Output: [ 79 628   5 198 452   0   0   0]
# Sequence 49875 in x
#   Input:  [   8   76  178  648 1572]
#   Output: [   8   76  178  648 1572    0    0    0]
# Sequence 49876 in x
#   Input:  [ 68   4 218  34   6 171]
#   Output: [ 68   4 218  34   6 171   0   0]
# Sequence 49877 in x
#   Input:  [68 10 56 67 29  6 81]
#   Output: [68 10 56 67 29  6 81  0]
# Sequence 49878 in x
#   Input:  [68 10 56 67 29  6 81]
#   Output: [68 10 56 67 29  6 81  0]
# Sequence 49879 in x
#   Input:  [ 68  10 479  47   7 337]
#   Output: [ 68  10 479  47   7 337   0   0]
# Sequence 49880 in x
#   Input:  [ 61 297 812 260  84]
#   Output: [ 61 297 812 260  84   0   0   0]
# Sequence 49881 in x
#   Input:  [  61  347 2890   57 1203]
#   Output: [  61  347 2890   57 1203    0    0    0]
# Sequence 49882 in x
#   Input:  [  61  347 2890   57 1203]
#   Output: [  61  347 2890   57 1203    0    0    0]
# Sequence 49883 in x
#   Input:  [  61  398  663    7 3074]
#   Output: [  61  398  663    7 3074    0    0    0]
# Sequence 49884 in x
#   Input:  [  61  331    4  889   57 2339]
#   Output: [  61  331    4  889   57 2339    0    0]
# Sequence 49885 in x
#   Input:  [ 61 149   4 757   6 680]
#   Output: [ 61 149   4 757   6 680   0   0]
# Sequence 49886 in x
#   Input:  [  61   98 6928   61 1752]
#   Output: [  61   98 6928   61 1752    0    0    0]
# Sequence 49887 in x
#   Input:  [  61  190   15 4574  186]
#   Output: [  61  190   15 4574  186    0    0    0]
# Sequence 49888 in x
#   Input:  [  61  190   15 4574  186]
#   Output: [  61  190   15 4574  186    0    0    0]
# Sequence 49889 in x
#   Input:  [ 61 147 246   4 115 584]
#   Output: [ 61 147 246   4 115 584   0   0]
# Sequence 49890 in x
#   Input:  [  61 1451   15  483   29 6929]
#   Output: [  61 1451   15  483   29 6929    0    0]
# Sequence 49891 in x
#   Input:  [  61 6930  205   62 6931]
#   Output: [  61 6930  205   62 6931    0    0    0]
# Sequence 49892 in x
#   Input:  [  61 6932 6933   34    6 1819]
#   Output: [  61 6932 6933   34    6 1819    0    0]
# Sequence 49893 in x
#   Input:  [  38    4   75   29   13 1010]
#   Output: [  38    4   75   29   13 1010    0    0]
# Sequence 49894 in x
#   Input:  [  38    4   75   29   13 1010]
#   Output: [  38    4   75   29   13 1010    0    0]
# Sequence 49895 in x
#   Input:  [ 768   13 1225  642]
#   Output: [ 768   13 1225  642    0    0    0    0]
# Sequence 49896 in x
#   Input:  [708   1  51   7 162   7   2]
#   Output: [708   1  51   7 162   7   2   0]
# Sequence 49897 in x
#   Input:  [  41 1636  486 2026]
#   Output: [  41 1636  486 2026    0    0    0    0]
# Sequence 49898 in x
#   Input:  [  41   81    4 2195    7  220]
#   Output: [  41   81    4 2195    7  220    0    0]
# Sequence 49899 in x
#   Input:  [ 41 565 705  77  52]
#   Output: [ 41 565 705  77  52   0   0   0]
# Sequence 49900 in x
#   Input:  [  41 2834   64  867  895]
#   Output: [  41 2834   64  867  895    0    0    0]
# Sequence 49901 in x
#   Input:  [  41  347 2890   57 1203]
#   Output: [  41  347 2890   57 1203    0    0    0]
# Sequence 49902 in x
#   Input:  [  41  200   15    5 1162]
#   Output: [  41  200   15    5 1162    0    0    0]
# Sequence 49903 in x
#   Input:  [ 41 720   4 475]
#   Output: [ 41 720   4 475   0   0   0   0]
# Sequence 49904 in x
#   Input:  [ 41 720   4 475]
#   Output: [ 41 720   4 475   0   0   0   0]
# Sequence 49905 in x
#   Input:  [ 41 523 114  77  52 701]
#   Output: [ 41 523 114  77  52 701   0   0]
# Sequence 49906 in x
#   Input:  [  41 4575   16   40  198]
#   Output: [  41 4575   16   40  198    0    0    0]
# Sequence 49907 in x
#   Input:  [  41 4575   16   40  198]
#   Output: [  41 4575   16   40  198    0    0    0]
# Sequence 49908 in x
#   Input:  [  41 6934    4  444 2183]
#   Output: [  41 6934    4  444 2183    0    0    0]
# Sequence 49909 in x
#   Input:  [  41  190    4 1771    7   77]
#   Output: [  41  190    4 1771    7   77    0    0]
# Sequence 49910 in x
#   Input:  [ 41 147 246   4 115 584]
#   Output: [ 41 147 246   4 115 584   0   0]
# Sequence 49911 in x
#   Input:  [  41 2425   15 4548]
#   Output: [  41 2425   15 4548    0    0    0    0]
# Sequence 49912 in x
#   Input:  [ 41 460 486   5 317]
#   Output: [ 41 460 486   5 317   0   0   0]
# Sequence 49913 in x
#   Input:  [  41  379    4 1295  671  147]
#   Output: [  41  379    4 1295  671  147    0    0]
# Sequence 49914 in x
#   Input:  [  41  379 3427   57  750]
#   Output: [  41  379 3427   57  750    0    0    0]
# Sequence 49915 in x
#   Input:  [  41 1066   11  118   36   53]
#   Output: [  41 1066   11  118   36   53    0    0]
# Sequence 49916 in x
#   Input:  [  41 4527   15    6  319]
#   Output: [  41 4527   15    6  319    0    0    0]
# Sequence 49917 in x
#   Input:  [  41   94    4  645 2351]
#   Output: [  41   94    4  645 2351    0    0    0]
# Sequence 49918 in x
#   Input:  [6935    4    5  474  934]
#   Output: [6935    4    5  474  934    0    0    0]
# Sequence 49919 in x
#   Input:  [2415  129  177  203]
#   Output: [2415  129  177  203    0    0    0    0]
# Sequence 49920 in x
#   Input:  [ 47  90  20 346 197]
#   Output: [ 47  90  20 346 197   0   0   0]
# Sequence 49921 in x
#   Input:  [ 47  90  20 346 197]
#   Output: [ 47  90  20 346 197   0   0   0]
# Sequence 49922 in x
#   Input:  [ 47  25   1 476  21 316]
#   Output: [ 47  25   1 476  21 316   0   0]
# Sequence 49923 in x
#   Input:  [  47   25    1  286    6 1746]
#   Output: [  47   25    1  286    6 1746    0    0]
# Sequence 49924 in x
#   Input:  [ 47  54   8  69 299  48]
#   Output: [ 47  54   8  69 299  48   0   0]
# Sequence 49925 in x
#   Input:  [ 47  33   6 441  56  67]
#   Output: [ 47  33   6 441  56  67   0   0]
# Sequence 49926 in x
#   Input:  [ 47  33  12 305   7   2]
#   Output: [ 47  33  12 305   7   2   0   0]
# Sequence 49927 in x
#   Input:  [ 47  33   2 188  19 107]
#   Output: [ 47  33   2 188  19 107   0   0]
# Sequence 49928 in x
#   Input:  [ 47  33   2  56  12 105]
#   Output: [ 47  33   2  56  12 105   0   0]
# Sequence 49929 in x
#   Input:  [47 33  2 37  9 15 10]
#   Output: [47 33  2 37  9 15 10  0]
# Sequence 49930 in x
#   Input:  [ 47  33   2 154  12 585]
#   Output: [ 47  33   2 154  12 585   0   0]
# Sequence 49931 in x
#   Input:  [ 47  11   1  56   7   6 737]
#   Output: [ 47  11   1  56   7   6 737   0]
# Sequence 49932 in x
#   Input:  [ 47  11   1  56   7  21 149]
#   Output: [ 47  11   1  56   7  21 149   0]
# Sequence 49933 in x
#   Input:  [ 47  11   1  56   7  21 149]
#   Output: [ 47  11   1  56   7  21 149   0]
# Sequence 49934 in x
#   Input:  [ 47  11   1  56   7  21 149]
#   Output: [ 47  11   1  56   7  21 149   0]
# Sequence 49935 in x
#   Input:  [  47   11    2  185   12 3238]
#   Output: [  47   11    2  185   12 3238    0    0]
# Sequence 49936 in x
#   Input:  [  47   11    2 2880   19  431]
#   Output: [  47   11    2 2880   19  431    0    0]
# Sequence 49937 in x
#   Input:  [  47   11    2 2880   19  431]
#   Output: [  47   11    2 2880   19  431    0    0]
# Sequence 49938 in x
#   Input:  [  47   11    2  108  128 1724]
#   Output: [  47   11    2  108  128 1724    0    0]
# Sequence 49939 in x
#   Input:  [  47   11    2  108  128 1724]
#   Output: [  47   11    2  108  128 1724    0    0]
# Sequence 49940 in x
#   Input:  [ 47  11   2 257  12 507]
#   Output: [ 47  11   2 257  12 507   0   0]
# Sequence 49941 in x
#   Input:  [ 47 117   3 142  90   9]
#   Output: [ 47 117   3 142  90   9   0   0]
# Sequence 49942 in x
#   Input:  [  47 1257    4   21 1398]
#   Output: [  47 1257    4   21 1398    0    0    0]
# Sequence 49943 in x
#   Input:  [ 47 198  16   2  92  35]
#   Output: [ 47 198  16   2  92  35   0   0]
# Sequence 49944 in x
#   Input:  [ 47 198  33   3  94  38]
#   Output: [ 47 198  33   3  94  38   0   0]
# Sequence 49945 in x
#   Input:  [ 47 198  33   3  94  38]
#   Output: [ 47 198  33   3  94  38   0   0]
# Sequence 49946 in x
#   Input:  [ 47 198  11   1  17   7 130]
#   Output: [ 47 198  11   1  17   7 130   0]
# Sequence 49947 in x
#   Input:  [ 47 198  11   1  17   7 155]
#   Output: [ 47 198  11   1  17   7 155   0]
# Sequence 49948 in x
#   Input:  [ 47 198  11   1  17   7 155]
#   Output: [ 47 198  11   1  17   7 155   0]
# Sequence 49949 in x
#   Input:  [ 47 198 117   5 867 245]
#   Output: [ 47 198 117   5 867 245   0   0]
# Sequence 49950 in x
#   Input:  [ 47 198  45  22 131 306]
#   Output: [ 47 198  45  22 131 306   0   0]
# Sequence 49951 in x
#   Input:  [  47  198    4    6 6936  878]
#   Output: [  47  198    4    6 6936  878    0    0]
# Sequence 49952 in x
#   Input:  [ 47 456   7 346   2  38]
#   Output: [ 47 456   7 346   2  38   0   0]
# Sequence 49953 in x
#   Input:  [ 47 248  16  24  21 653]
#   Output: [ 47 248  16  24  21 653   0   0]
# Sequence 49954 in x
#   Input:  [ 47 248 297  11   2  17]
#   Output: [ 47 248 297  11   2  17   0   0]
# Sequence 49955 in x
#   Input:  [ 47 248 297  11   2  17]
#   Output: [ 47 248 297  11   2  17   0   0]
# Sequence 49956 in x
#   Input:  [  47  248 6937   11    2   17]
#   Output: [  47  248 6937   11    2   17    0    0]
# Sequence 49957 in x
#   Input:  [  47  248 3355   43   55]
#   Output: [  47  248 3355   43   55    0    0    0]
# Sequence 49958 in x
#   Input:  [  47  248 2774   33    2 3077]
#   Output: [  47  248 2774   33    2 3077    0    0]
# Sequence 49959 in x
#   Input:  [  47  248 2474   16   55]
#   Output: [  47  248 2474   16   55    0    0    0]
# Sequence 49960 in x
#   Input:  [  47  248 2129   11    2   17]
#   Output: [  47  248 2129   11    2   17    0    0]
# Sequence 49961 in x
#   Input:  [  47  248 2129   11    2   17]
#   Output: [  47  248 2129   11    2   17    0    0]
# Sequence 49962 in x
#   Input:  [  47  248 2129   11    2   17]
#   Output: [  47  248 2129   11    2   17    0    0]
# Sequence 49963 in x
#   Input:  [  47  248 1215   16   55]
#   Output: [  47  248 1215   16   55    0    0    0]
# Sequence 49964 in x
#   Input:  [ 47 119 105  33   2 402]
#   Output: [ 47 119 105  33   2 402   0   0]
# Sequence 49965 in x
#   Input:  [ 47 119 105  11   2  17]
#   Output: [ 47 119 105  11   2  17   0   0]
# Sequence 49966 in x
#   Input:  [ 47 119 105  11   2  31]
#   Output: [ 47 119 105  11   2  31   0   0]
# Sequence 49967 in x
#   Input:  [ 47 119 105  11   2  31]
#   Output: [ 47 119 105  11   2  31   0   0]
# Sequence 49968 in x
#   Input:  [ 47 119 105  11   2  31]
#   Output: [ 47 119 105  11   2  31   0   0]
# Sequence 49969 in x
#   Input:  [ 47 119 105  11   2  31]
#   Output: [ 47 119 105  11   2  31   0   0]
# Sequence 49970 in x
#   Input:  [ 47 119 272  11   2  17]
#   Output: [ 47 119 272  11   2  17   0   0]
# Sequence 49971 in x
#   Input:  [  47  310   11    2   32 1152]
#   Output: [  47  310   11    2   32 1152    0    0]
# Sequence 49972 in x
#   Input:  [ 47 310 117  19 305]
#   Output: [ 47 310 117  19 305   0   0   0]
# Sequence 49973 in x
#   Input:  [  47  147    4   21 2580  379]
#   Output: [  47  147    4   21 2580  379    0    0]
# Sequence 49974 in x
#   Input:  [  47   15    1 2891    7   37]
#   Output: [  47   15    1 2891    7   37    0    0]
# Sequence 49975 in x
#   Input:  [  47   15    1 2891    7   37]
#   Output: [  47   15    1 2891    7   37    0    0]
# Sequence 49976 in x
#   Input:  [   1 3574    5  146    7   13  149]
#   Output: [   1 3574    5  146    7   13  149    0]
# Sequence 49977 in x
#   Input:  [   1 2501   42   27    7  337]
#   Output: [   1 2501   42   27    7  337    0    0]
# Sequence 49978 in x
#   Input:  [   1  218  228    6 4131]
#   Output: [   1  218  228    6 4131    0    0    0]
# Sequence 49979 in x
#   Input:  [  1 218  37  72   2  16]
#   Output: [  1 218  37  72   2  16   0   0]
# Sequence 49980 in x
#   Input:  [  1 177 169 136   6 525]
#   Output: [  1 177 169 136   6 525   0   0]
# Sequence 49981 in x
#   Input:  [   1   66    5  173 2065   29    6 6938]
#   Output: [   1   66    5  173 2065   29    6 6938]
# Sequence 49982 in x
#   Input:  [   1   66   70 3674  136 1507]
#   Output: [   1   66   70 3674  136 1507    0    0]
# Sequence 49983 in x
#   Input:  [   1   66   46   89  288 1462]
#   Output: [   1   66   46   89  288 1462    0    0]
# Sequence 49984 in x
#   Input:  [   1   66 6939   13 1567]
#   Output: [   1   66 6939   13 1567    0    0    0]
# Sequence 49985 in x
#   Input:  [   1   66  833 1036    9]
#   Output: [   1   66  833 1036    9    0    0    0]
# Sequence 49986 in x
#   Input:  [   1   66 6940  671  147]
#   Output: [   1   66 6940  671  147    0    0    0]
# Sequence 49987 in x
#   Input:  [   1   66   92  123    6 1261]
#   Output: [   1   66   92  123    6 1261    0    0]
# Sequence 49988 in x
#   Input:  [  1  66 109   7  63   2  38]
#   Output: [  1  66 109   7  63   2  38   0]
# Sequence 49989 in x
#   Input:  [   1   66   24   62 1220   35  684]
#   Output: [   1   66   24   62 1220   35  684    0]
# Sequence 49990 in x
#   Input:  [   1   66 1154   24  328]
#   Output: [   1   66 1154   24  328    0    0    0]
# Sequence 49991 in x
#   Input:  [  1  66  71  92  35   5 308]
#   Output: [  1  66  71  92  35   5 308   0]
# Sequence 49992 in x
#   Input:  [   1   66   95  349   34 2062]
#   Output: [   1   66   95  349   34 2062    0    0]
# Sequence 49993 in x
#   Input:  [  1  66  27 109  57  13 141]
#   Output: [  1  66  27 109  57  13 141   0]
# Sequence 49994 in x
#   Input:  [   1   66  405  473 1729]
#   Output: [   1   66  405  473 1729    0    0    0]
# Sequence 49995 in x
#   Input:  [   1   66  571    5 6941 2704]
#   Output: [   1   66  571    5 6941 2704    0    0]
# Sequence 49996 in x
#   Input:  [   1   66  207   29 2458   19]
#   Output: [   1   66  207   29 2458   19    0    0]
# Sequence 49997 in x
#   Input:  [   1   66   48    7   13 1873   24   94]
#   Output: [   1   66   48    7   13 1873   24   94]
# Sequence 49998 in x
#   Input:  [  1  66 406  35  13 968]
#   Output: [  1  66 406  35  13 968   0   0]
# Sequence 49999 in x
#   Input:  [  1 940  52  21  68]
#   Output: [  1 940  52  21  68   0   0   0]
# Sequence 50000 in x
#   Input:  [   1  940   21 2596]
#   Output: [   1  940   21 2596    0    0    0    0]

# %%
test_esp_pad = pad(esp_tokenized)

for sample_i, (token_sent, pad_sent) in enumerate(zip(esp_tokenized, test_esp_pad)):
    print('Sequence {} in x'.format(sample_i + 1))
    print('  Input:  {}'.format(np.array(token_sent)))
    print('  Output: {}'.format(pad_sent))
# Out:
# 0]
# Sequence 49846 in x
#   Input:  [ 623    7 1221    6  246  920]
#   Output: [ 623    7 1221    6  246  920    0    0    0    0    0    0]
# Sequence 49847 in x
#   Input:  [  11 1243   32   40 7432    9   86]
#   Output: [  11 1243   32   40 7432    9   86    0    0    0    0    0]
# Sequence 49848 in x
#   Input:  [  11  396 1312  946   47  142]
#   Output: [  11  396 1312  946   47  142    0    0    0    0    0    0]
# Sequence 49849 in x
#   Input:  [  11  396   15    7 6533]
#   Output: [  11  396   15    7 6533    0    0    0    0    0    0    0]
# Sequence 49850 in x
#   Input:  [  11 7323    9 3532]
#   Output: [  11 7323    9 3532    0    0    0    0    0    0    0    0]
# Sequence 49851 in x
#   Input:  [   11     3     8  2120 14167    32     6   976]
#   Output: [   11     3     8  2120 14167    32     6   976     0     0     0     0]
# Sequence 49852 in x
#   Input:  [  11    3    8 2120 3663    5    6  976]
#   Output: [  11    3    8 2120 3663    5    6  976    0    0    0    0]
# Sequence 49853 in x
#   Input:  [ 11   3   8 143  15   7   9 108 621]
#   Output: [ 11   3   8 143  15   7   9 108 621   0   0   0]
# Sequence 49854 in x
#   Input:  [ 11   3 422  75  23 175]
#   Output: [ 11   3 422  75  23 175   0   0   0   0   0   0]
# Sequence 49855 in x
#   Input:  [  11    3   16  290   28 1890]
#   Output: [  11    3   16  290   28 1890    0    0    0    0    0    0]
# Sequence 49856 in x
#   Input:  [  11    3 2535    4    6  193 7521]
#   Output: [  11    3 2535    4    6  193 7521    0    0    0    0    0]
# Sequence 49857 in x
#   Input:  [ 11 123 832 131   4 869]
#   Output: [ 11 123 832 131   4 869   0   0   0   0   0   0]
# Sequence 49858 in x
#   Input:  [   11   123    12   585 14168]
#   Output: [   11   123    12   585 14168     0     0     0     0     0     0     0]
# Sequence 49859 in x
#   Input:  [ 11 123  37 626   5 101]
#   Output: [ 11 123  37 626   5 101   0   0   0   0   0   0]
# Sequence 49860 in x
#   Input:  [  11  123   12 1189    5 1685]
#   Output: [  11  123   12 1189    5 1685    0    0    0    0    0    0]
# Sequence 49861 in x
#   Input:  [ 123 1127 1189    5  101]
#   Output: [ 123 1127 1189    5  101    0    0    0    0    0    0    0]
# Sequence 49862 in x
#   Input:  [  11 3024    2  768]
#   Output: [  11 3024    2  768    0    0    0    0    0    0    0    0]
# Sequence 49863 in x
#   Input:  [  12 2452   27 1714 3876]
#   Output: [  12 2452   27 1714 3876    0    0    0    0    0    0    0]
# Sequence 49864 in x
#   Input:  [  11   12 2452   27 1714 3876]
#   Output: [  11   12 2452   27 1714 3876    0    0    0    0    0    0]
# Sequence 49865 in x
#   Input:  [ 11  12 218  78 125]
#   Output: [ 11  12 218  78 125   0   0   0   0   0   0   0]
# Sequence 49866 in x
#   Input:  [  12 2367  118  264]
#   Output: [  12 2367  118  264    0    0    0    0    0    0    0    0]
# Sequence 49867 in x
#   Input:  [  11   13  111    5 3128    4 1523]
#   Output: [  11   13  111    5 3128    4 1523    0    0    0    0    0]
# Sequence 49868 in x
#   Input:  [ 11   3 601  15  57]
#   Output: [ 11   3 601  15  57   0   0   0   0   0   0   0]
# Sequence 49869 in x
#   Input:  [   3   40   52  411    9 1082]
#   Output: [   3   40   52  411    9 1082    0    0    0    0    0    0]
# Sequence 49870 in x
#   Input:  [ 11   3  40 487   9  53]
#   Output: [ 11   3  40 487   9  53   0   0   0   0   0   0]
# Sequence 49871 in x
#   Input:  [  11    3  473 2190 6928]
#   Output: [  11    3  473 2190 6928    0    0    0    0    0    0    0]
# Sequence 49872 in x
#   Input:  [  11    3    7 2970    5    8  564]
#   Output: [  11    3    7 2970    5    8  564    0    0    0    0    0]
# Sequence 49873 in x
#   Input:  [   3    7 4235    5    6 4966]
#   Output: [   3    7 4235    5    6 4966    0    0    0    0    0    0]
# Sequence 49874 in x
#   Input:  [  11   12 1025   16 1076  382]
#   Output: [  11   12 1025   16 1076  382    0    0    0    0    0    0]
# Sequence 49875 in x
#   Input:  [  175    11 14169  1461]
#   Output: [  175    11 14169  1461     0     0     0     0     0     0     0     0]
# Sequence 49876 in x
#   Input:  [  6 138  79  12  15 343]
#   Output: [  6 138  79  12  15 343   0   0   0   0   0   0]
# Sequence 49877 in x
#   Input:  [1116    4 2955  115  126]
#   Output: [1116    4 2955  115  126    0    0    0    0    0    0    0]
# Sequence 49878 in x
#   Input:  [3748    4  356  115  126]
#   Output: [3748    4  356  115  126    0    0    0    0    0    0    0]
# Sequence 49879 in x
#   Input:  [1116    4  684    4  647]
#   Output: [1116    4  684    4  647    0    0    0    0    0    0    0]
# Sequence 49880 in x
#   Input:  [ 145  253   13 2368   28   52]
#   Output: [ 145  253   13 2368   28   52    0    0    0    0    0    0]
# Sequence 49881 in x
#   Input:  [  25  284    5   18   13 5359    5 1993]
#   Output: [  25  284    5   18   13 5359    5 1993    0    0    0    0]
# Sequence 49882 in x
#   Input:  [ 145  284   13 5359    5 1993]
#   Output: [ 145  284   13 5359    5 1993    0    0    0    0    0    0]
# Sequence 49883 in x
#   Input:  [  27  338   13 3578    4 4657]
#   Output: [  27  338   13 3578    4 4657    0    0    0    0    0    0]
# Sequence 49884 in x
#   Input:  [  27  286   12 2725   32    7 7559]
#   Output: [  27  286   12 2725   32    7 7559    0    0    0    0    0]
# Sequence 49885 in x
#   Input:  [  27   48   12  308  115 1285]
#   Output: [  27   48   12  308  115 1285    0    0    0    0    0    0]
# Sequence 49886 in x
#   Input:  [   27  1959 14170    27  2309]
#   Output: [   27  1959 14170    27  2309     0     0     0     0     0     0     0]
# Sequence 49887 in x
#   Input:  [   27   190    46 14171   161]
#   Output: [   27   190    46 14171   161     0     0     0     0     0     0     0]
# Sequence 49888 in x
#   Input:  [14172   161    27   190]
#   Output: [14172   161    27   190     0     0     0     0     0     0     0     0]
# Sequence 49889 in x
#   Input:  [ 27 362 208 130  12 364]
#   Output: [ 27 362 208 130  12 364   0   0   0   0   0   0]
# Sequence 49890 in x
#   Input:  [   27  1838 14173     5 14174]
#   Output: [   27  1838 14173     5 14174     0     0     0     0     0     0     0]
# Sequence 49891 in x
#   Input:  [   27 14175     2    37  4708]
#   Output: [   27 14175     2    37  4708     0     0     0     0     0     0     0]
# Sequence 49892 in x
#   Input:  [   27    48    13 14176    15     6  2389]
#   Output: [   27    48    13 14176    15     6  2389     0     0     0     0     0]
# Sequence 49893 in x
#   Input:  [ 30 105  16 712 435]
#   Output: [ 30 105  16 712 435   0   0   0   0   0   0   0]
# Sequence 49894 in x
#   Input:  [  30  105   16  712 1695   19   17]
#   Output: [  30  105   16  712 1695   19   17    0    0    0    0    0]
# Sequence 49895 in x
#   Input:  [ 30  92  17 648   5 266]
#   Output: [ 30  92  17 648   5 266   0   0   0   0   0   0]
# Sequence 49896 in x
#   Input:  [2375   83  118   32  447]
#   Output: [2375   83  118   32  447    0    0    0    0    0    0    0]
# Sequence 49897 in x
#   Input:  [   27  3315    13   423 14177]
#   Output: [   27  3315    13   423 14177     0     0     0     0     0     0     0]
# Sequence 49898 in x
#   Input:  [  27  126    3 7507   47  289]
#   Output: [  27  126    3 7507   47  289    0    0    0    0    0    0]
# Sequence 49899 in x
#   Input:  [  27  653   61 1805    4   58]
#   Output: [  27  653   61 1805    4   58    0    0    0    0    0    0]
# Sequence 49900 in x
#   Input:  [  27 1958 3461 7596]
#   Output: [  27 1958 3461 7596    0    0    0    0    0    0    0    0]
# Sequence 49901 in x
#   Input:  [ 145  284   13 5359    5 1993]
#   Output: [ 145  284   13 5359    5 1993    0    0    0    0    0    0]
# Sequence 49902 in x
#   Input:  [ 27 160  69 499]
#   Output: [ 27 160  69 499   0   0   0   0   0   0   0   0]
# Sequence 49903 in x
#   Input:  [  27  735    3 1417]
#   Output: [  27  735    3 1417    0    0    0    0    0    0    0    0]
# Sequence 49904 in x
#   Input:  [  27  707    3 1417]
#   Output: [  27  707    3 1417    0    0    0    0    0    0    0    0]
# Sequence 49905 in x
#   Input:  [ 27 629  61  99 982   4  58]
#   Output: [ 27 629  61  99 982   4  58   0   0   0   0   0]
# Sequence 49906 in x
#   Input:  [  145 14178    43    28  5268]
#   Output: [  145 14178    43    28  5268     0     0     0     0     0     0     0]
# Sequence 49907 in x
#   Input:  [  145 14179    43    28  1948]
#   Output: [  145 14179    43    28  1948     0     0     0     0     0     0     0]
# Sequence 49908 in x
#   Input:  [  14    9   11  708    5  207    3   52 2767    5 7586]
#   Output: [  14    9   11  708    5  207    3   52 2767    5 7586    0]
# Sequence 49909 in x
#   Input:  [  27  190   61 2923 2924]
#   Output: [  27  190   61 2923 2924    0    0    0    0    0    0    0]
# Sequence 49910 in x
#   Input:  [ 27 362 208 130  12 364]
#   Output: [ 27 362 208 130  12 364   0   0   0   0   0   0]
# Sequence 49911 in x
#   Input:  [  27 3457   13 2077]
#   Output: [  27 3457   13 2077    0    0    0    0    0    0    0    0]
# Sequence 49912 in x
#   Input:  [  27  393   13   99 2759]
#   Output: [  27  393   13   99 2759    0    0    0    0    0    0    0]
# Sequence 49913 in x
#   Input:  [  27  274   37 1312  226]
#   Output: [  27  274   37 1312  226    0    0    0    0    0    0    0]
# Sequence 49914 in x
#   Input:  [  27  274 7585    5 3903]
#   Output: [  27  274 7585    5 3903    0    0    0    0    0    0    0]
# Sequence 49915 in x
#   Input:  [  145   385   940    14     9    13   189 14180]
#   Output: [  145   385   940    14     9    13   189 14180     0     0     0     0]
# Sequence 49916 in x
#   Input:  [  27 7572   69    6  128]
#   Output: [  27 7572   69    6  128    0    0    0    0    0    0    0]
# Sequence 49917 in x
#   Input:  [  27   81    3   82 5689]
#   Output: [  27   81    3   82 5689    0    0    0    0    0    0    0]
# Sequence 49918 in x
#   Input:  [7566    3    8 1440  581]
#   Output: [7566    3    8 1440  581    0    0    0    0    0    0    0]
# Sequence 49919 in x
#   Input:  [   6 4045    2  123  970]
#   Output: [   6 4045    2  123  970    0    0    0    0    0    0    0]
# Sequence 49920 in x
#   Input:  [  35  301  209 1254  140]
#   Output: [  35  301  209 1254  140    0    0    0    0    0    0    0]
# Sequence 49921 in x
#   Input:  [  35   20  116  209 1254  140]
#   Output: [  35   20  116  209 1254  140    0    0    0    0    0    0]
# Sequence 49922 in x
#   Input:  [  77   49 2681 1067    5  801]
#   Output: [  77   49 2681 1067    5  801    0    0    0    0    0    0]
# Sequence 49923 in x
#   Input:  [  77   49 2999    7 2108]
#   Output: [  77   49 2999    7 2108    0    0    0    0    0    0    0]
# Sequence 49924 in x
#   Input:  [  77    3    9    2 1435]
#   Output: [  77    3    9    2 1435    0    0    0    0    0    0    0]
# Sequence 49925 in x
#   Input:  [   77    13 14181     7   419]
#   Output: [   77    13 14181     7   419     0     0     0     0     0     0     0]
# Sequence 49926 in x
#   Input:  [ 77  20 277  29]
#   Output: [ 77  20 277  29   0   0   0   0   0   0   0   0]
# Sequence 49927 in x
#   Input:  [  77 1947   93   90]
#   Output: [  77 1947   93   90    0    0    0    0    0    0    0    0]
# Sequence 49928 in x
#   Input:  [  77 7286   44  101]
#   Output: [  77 7286   44  101    0    0    0    0    0    0    0    0]
# Sequence 49929 in x
#   Input:  [   77 14182     9   240    23]
#   Output: [   77 14182     9   240    23     0     0     0     0     0     0     0]
# Sequence 49930 in x
#   Input:  [ 77 401  55 577]
#   Output: [ 77 401  55 577   0   0   0   0   0   0   0   0]
# Sequence 49931 in x
#   Input:  [ 77  13 832   4   6 499]
#   Output: [ 77  13 832   4   6 499   0   0   0   0   0   0]
# Sequence 49932 in x
#   Input:  [77 84  4 36 48]
#   Output: [77 84  4 36 48  0  0  0  0  0  0  0]
# Sequence 49933 in x
#   Input:  [ 77  13 111   4 878  48]
#   Output: [ 77  13 111   4 878  48   0   0   0   0   0   0]
# Sequence 49934 in x
#   Input:  [  77 1729    4   36   48]
#   Output: [  77 1729    4   36   48    0    0    0    0    0    0    0]
# Sequence 49935 in x
#   Input:  [  77   13 1017   44 4949]
#   Output: [  77   13 1017   44 4949    0    0    0    0    0    0    0]
# Sequence 49936 in x
#   Input:  [   77    13 14183   112   476]
#   Output: [   77    13 14183   112   476     0     0     0     0     0     0     0]
# Sequence 49937 in x
#   Input:  [ 77  13 897 112 476]
#   Output: [ 77  13 897 112 476   0   0   0   0   0   0   0]
# Sequence 49938 in x
#   Input:  [   77   108 14184]
#   Output: [   77   108 14184     0     0     0     0     0     0     0     0     0]
# Sequence 49939 in x
#   Input:  [   77   658 14185]
#   Output: [   77   658 14185     0     0     0     0     0     0     0     0     0]
# Sequence 49940 in x
#   Input:  [  77   13 1083   55  484]
#   Output: [  77   13 1083   55  484    0    0    0    0    0    0    0]
# Sequence 49941 in x
#   Input:  [ 77  13 845   1 558   5  24]
#   Output: [ 77  13 845   1 558   5  24   0   0   0   0   0]
# Sequence 49942 in x
#   Input:  [ 270 4217  878 1976]
#   Output: [ 270 4217  878 1976    0    0    0    0    0    0    0    0]
# Sequence 49943 in x
#   Input:  [  54 1530   97  292]
#   Output: [  54 1530   97  292    0    0    0    0    0    0    0    0]
# Sequence 49944 in x
#   Input:  [ 270   97 1243    1  372]
#   Output: [ 270   97 1243    1  372    0    0    0    0    0    0    0]
# Sequence 49945 in x
#   Input:  [ 270   97 1243   30    1]
#   Output: [ 270   97 1243   30    1    0    0    0    0    0    0    0]
# Sequence 49946 in x
#   Input:  [  54 1530   10   31    9  995]
#   Output: [  54 1530   10   31    9  995    0    0    0    0    0    0]
# Sequence 49947 in x
#   Input:  [  54 1530   31    9  359]
#   Output: [  54 1530   31    9  359    0    0    0    0    0    0    0]
# Sequence 49948 in x
#   Input:  [270  31   9 359]
#   Output: [270  31   9 359   0   0   0   0   0   0   0   0]
# Sequence 49949 in x
#   Input:  [ 270   97 1265    8 1917]
#   Output: [ 270   97 1265    8 1917    0    0    0    0    0    0    0]
# Sequence 49950 in x
#   Input:  [7402 2394  114    9   18   12  858]
#   Output: [7402 2394  114    9   18   12  858    0    0    0    0    0]
# Sequence 49951 in x
#   Input:  [  152     3     6  7305   115   943 14186]
#   Output: [  152     3     6  7305   115   943 14186     0     0     0     0     0]
# Sequence 49952 in x
#   Input:  [  34 1429    5  367   30]
#   Output: [  34 1429    5  367   30    0    0    0    0    0    0    0]
# Sequence 49953 in x
#   Input:  [2178  938   43]
#   Output: [2178  938   43    0    0    0    0    0    0    0    0    0]
# Sequence 49954 in x
#   Input:  [506 253  92]
#   Output: [506 253  92   0   0   0   0   0   0   0   0   0]
# Sequence 49955 in x
#   Input:  [506 253  37  95]
#   Output: [506 253  37  95   0   0   0   0   0   0   0   0]
# Sequence 49956 in x
#   Input:  [ 2178 14187    92]
#   Output: [ 2178 14187    92     0     0     0     0     0     0     0     0     0]
# Sequence 49957 in x
#   Input:  [ 506 5123  327]
#   Output: [ 506 5123  327    0    0    0    0    0    0    0    0    0]
# Sequence 49958 in x
#   Input:  [  506  3317 14188]
#   Output: [  506  3317 14188     0     0     0     0     0     0     0     0     0]
# Sequence 49959 in x
#   Input:  [ 506 3500  105]
#   Output: [ 506 3500  105    0    0    0    0    0    0    0    0    0]
# Sequence 49960 in x
#   Input:  [2178 5343   92]
#   Output: [2178 5343   92    0    0    0    0    0    0    0    0    0]
# Sequence 49961 in x
#   Input:  [2178 5343  532]
#   Output: [2178 5343  532    0    0    0    0    0    0    0    0    0]
# Sequence 49962 in x
#   Input:  [  506 14189   532]
#   Output: [  506 14189   532     0     0     0     0     0     0     0     0     0]
# Sequence 49963 in x
#   Input:  [2178 1455  105]
#   Output: [2178 1455  105    0    0    0    0    0    0    0    0    0]
# Sequence 49964 in x
#   Input:  [  270   101 14190]
#   Output: [  270   101 14190     0     0     0     0     0     0     0     0     0]
# Sequence 49965 in x
#   Input:  [270 101  92]
#   Output: [270 101  92   0   0   0   0   0   0   0   0   0]
# Sequence 49966 in x
#   Input:  [270 101 313]
#   Output: [270 101 313   0   0   0   0   0   0   0   0   0]
# Sequence 49967 in x
#   Input:  [270 101 107]
#   Output: [270 101 107   0   0   0   0   0   0   0   0   0]
# Sequence 49968 in x
#   Input:  [ 270  101 1926]
#   Output: [ 270  101 1926    0    0    0    0    0    0    0    0    0]
# Sequence 49969 in x
#   Input:  [270 101 587]
#   Output: [270 101 587   0   0   0   0   0   0   0   0   0]
# Sequence 49970 in x
#   Input:  [2356  206   92]
#   Output: [2356  206   92    0    0    0    0    0    0    0    0    0]
# Sequence 49971 in x
#   Input:  [ 775   34 1133  292   47 1060]
#   Output: [ 775   34 1133  292   47 1060    0    0    0    0    0    0]
# Sequence 49972 in x
#   Input:  [ 775   34 1133  378   24]
#   Output: [ 775   34 1133  378   24    0    0    0    0    0    0    0]
# Sequence 49973 in x
#   Input:  [506 226  37  36 274 643]
#   Output: [506 226  37  36 274 643   0   0   0   0   0   0]
# Sequence 49974 in x
#   Input:  [   77    13 14191     9    14  4515]
#   Output: [   77    13 14191     9    14  4515     0     0     0     0     0     0]
# Sequence 49975 in x
#   Input:  [  77  709    4 1048]
#   Output: [  77  709    4 1048    0    0    0    0    0    0    0    0]
# Sequence 49976 in x
#   Input:  [5672   16  184    4   17   48]
#   Output: [5672   16  184    4   17   48    0    0    0    0    0    0]
# Sequence 49977 in x
#   Input:  [   22 14192     9     2  4100]
#   Output: [   22 14192     9     2  4100     0     0     0     0     0     0     0]
# Sequence 49978 in x
#   Input:  [  79 1977    7 2615]
#   Output: [  79 1977    7 2615    0    0    0    0    0    0    0    0]
# Sequence 49979 in x
#   Input:  [  79   63 1269  183]
#   Output: [  79   63 1269  183    0    0    0    0    0    0    0    0]
# Sequence 49980 in x
#   Input:  [ 123  368 7576   26  702]
#   Output: [ 123  368 7576   26  702    0    0    0    0    0    0    0]
# Sequence 49981 in x
#   Input:  [  45    8  269 5559  115 1471]
#   Output: [  45    8  269 5559  115 1471    0    0    0    0    0    0]
# Sequence 49982 in x
#   Input:  [  45 2511   19 2071]
#   Output: [  45 2511   19 2071    0    0    0    0    0    0    0    0]
# Sequence 49983 in x
#   Input:  [  21   15   48  455   26 1834]
#   Output: [  21   15   48  455   26 1834    0    0    0    0    0    0]
# Sequence 49984 in x
#   Input:  [   21 14193    17  2658]
#   Output: [   21 14193    17  2658     0     0     0     0     0     0     0     0]
# Sequence 49985 in x
#   Input:  [  21  711   15 1037]
#   Output: [  21  711   15 1037    0    0    0    0    0    0    0    0]
# Sequence 49986 in x
#   Input:  [  31 3975   75  541  226]
#   Output: [  31 3975   75  541  226    0    0    0    0    0    0    0]
# Sequence 49987 in x
#   Input:  [  84 3954   26 1009]
#   Output: [  84 3954   26 1009    0    0    0    0    0    0    0    0]
# Sequence 49988 in x
#   Input:  [ 21 133   5 367  30]
#   Output: [ 21 133   5 367  30   0   0   0   0   0   0   0]
# Sequence 49989 in x
#   Input:  [  94    2 2121    5 1147   51 2960]
#   Output: [  94    2 2121    5 1147   51 2960    0    0    0    0    0]
# Sequence 49990 in x
#   Input:  [  21 2510   15    7  278]
#   Output: [  21 2510   15    7  278    0    0    0    0    0    0    0]
# Sequence 49991 in x
#   Input:  [ 229   84    4  469    8 1493]
#   Output: [ 229   84    4  469    8 1493    0    0    0    0    0    0]
# Sequence 49992 in x
#   Input:  [  86   21  346   25 1687]
#   Output: [  86   21  346   25 1687    0    0    0    0    0    0    0]
# Sequence 49993 in x
#   Input:  [  2  21 695  32  17  81]
#   Output: [  2  21 695  32  17  81   0   0   0   0   0   0]
# Sequence 49994 in x
#   Input:  [   21   585 14194  3985]
#   Output: [   21   585 14194  3985     0     0     0     0     0     0     0     0]
# Sequence 49995 in x
#   Input:  [   21  3757     8  2592 14195]
#   Output: [   21  3757     8  2592 14195     0     0     0     0     0     0     0]
# Sequence 49996 in x
#   Input:  [  21  926    5 1272   24]
#   Output: [  21  926    5 1272   24    0    0    0    0    0    0    0]
# Sequence 49997 in x
#   Input:  [  21  241    7 2477    5   81]
#   Output: [  21  241    7 2477    5   81    0    0    0    0    0    0]
# Sequence 49998 in x
#   Input:  [  21  365    4   17 3916]
#   Output: [  21  365    4   17 3916    0    0    0    0    0    0    0]
# Sequence 49999 in x
#   Input:  [1538  281   36  138]
#   Output: [1538  281   36  138    0    0    0    0    0    0    0    0]
# Sequence 50000 in x
#   Input:  [2217   36 5239]
#   Output: [2217   36 5239    0    0    0    0    0    0    0    0    0]

# %% [markdown]
# ### 4. Model Building

# %% [markdown]
# ### 4.1 Simple RNN

# %%
def preprocess(x, y):
    """
    Preprocess x and y
    :param x: Feature List of sentences
    :param y: Label List of sentences
    :return: Tuple of (Preprocessed x, Preprocessed y, x tokenizer, y tokenizer)
    """
    preprocess_x, x_tk = tokenize(x)
    preprocess_y, y_tk = tokenize(y)

    preprocess_x = pad(preprocess_x)
    preprocess_y = pad(preprocess_y)

    # Keras's sparse_categorical_crossentropy function requires the labels to be in 3 dimensions
    preprocess_y = preprocess_y.reshape(*preprocess_y.shape, 1)

    return preprocess_x, preprocess_y, x_tk, y_tk

# %%
preproc_english_sentences, preproc_spanish_sentences, english_tokenizer, spanish_tokenizer =\
    preprocess(data_eng_spa_processed[:,0], data_eng_spa_processed[:,1])

# %%
max_english_sequence_length = preproc_english_sentences.shape[1]
max_spanish_sequence_length = preproc_spanish_sentences.shape[1]
english_vocab_size = len(english_tokenizer.word_index)
spanish_vocab_size = len(spanish_tokenizer.word_index)

# %%
print('Data Preprocessed')
print("Max English sentence length:", max_english_sequence_length)
print("Max Spanish sentence length:", max_spanish_sequence_length)
print("English vocabulary size:", english_vocab_size)
print("Spanish vocabulary size:", spanish_vocab_size)
# Out:
# Data Preprocessed
# Max English sentence length: 8
# Max Spanish sentence length: 12
# English vocabulary size: 6941
# Spanish vocabulary size: 14195

# %%
def simple_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    """
    Build and train a basic RNN on x and y
    :param input_shape: Tuple of input shape
    :param output_sequence_length: Length of output sequence
    :param english_vocab_size: Number of unique English words in the dataset
    :param french_vocab_size: Number of unique French words in the dataset
    :return: Keras model built, but not trained
    """
    # Hyperparameters
    learning_rate = 0.005
    
    # TODO: Build the layers
    model = Sequential()
    model.add(GRU(256, input_shape=input_shape[1:], return_sequences=True))
    model.add(TimeDistributed(Dense(1024, activation='relu')))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(Dense(spanish_vocab_size + 1, activation='softmax'))) 

    # Compile model
    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    return model

# %%
# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, max_spanish_sequence_length)
tmp_x = tmp_x.reshape((-1, preproc_spanish_sentences.shape[-2], 1))

# %% [markdown]
# ### 4.2 NMT (Neural Machine Translation) Model
#
# Una vez se han definido los conjuntos de training y de test, se define también la arquitectura de un modelo Seq2Seq. Se usan tanto una capa Embedding como una capa LSTM como nuestro codificador y otra capa LSTM seguida de una capa densa como decodificador. Se utiliza, además, un optimizador de tipo RMSprop en este modelo, ya que suele ser una buena opción para redes neuronales recurrentes. En las siguientes celdas se lleva a cabo el entrenamiento así como el análisis de los resultados y se carga el modelo guardado con el filename especificado para realizar las predicciones sobre la muestra de test.

# %%
history=simple_rnn_model.fit(tmp_x, preproc_spanish_sentences, batch_size=1024, epochs=20, validation_split=0.2, callbacks=callback)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 8147s 209s/step - loss: 1.8931 - accuracy: 0.7114 - val_loss: 2.7739 - val_accuracy: 0.6218
#
# Epoch 00001: loss improved from 1.91816 to 1.89309, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 2/20
# 40/40 [==============================] - 185s 5s/step - loss: 1.8709 - accuracy: 0.7122 - val_loss: 2.7670 - val_accuracy: 0.6201
#
# Epoch 00002: loss improved from 1.89309 to 1.87091, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 3/20
# 40/40 [==============================] - 188s 5s/step - loss: 1.8557 - accuracy: 0.7125 - val_loss: 2.7815 - val_accuracy: 0.6228
#
# Epoch 00003: loss improved from 1.87091 to 1.85569, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 4/20
# 40/40 [==============================] - 191s 5s/step - loss: 1.8373 - accuracy: 0.7129 - val_loss: 2.7740 - val_accuracy: 0.6209
#
# Epoch 00004: loss improved from 1.85569 to 1.83733, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 5/20
# 40/40 [==============================] - 190s 5s/step - loss: 1.8213 - accuracy: 0.7135 - val_loss: 2.7765 - val_accuracy: 0.6240
#
# Epoch 00005: loss improved from 1.83733 to 1.82135, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 6/20
# 40/40 [==============================] - 521s 13s/step - loss: 1.8035 - accuracy: 0.7139 - val_loss: 2.8051 - val_accuracy: 0.6243
#
# Epoch 00006: loss improved from 1.82135 to 1.80348, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 7/20
# 40/40 [==============================] - 206s 5s/step - loss: 1.7921 - accuracy: 0.7145 - val_loss: 2.7841 - val_accuracy: 0.6245
#
# Epoch 00007: loss improved from 1.80348 to 1.79211, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 8/20
# 40/40 [==============================] - 195s 5s/step - loss: 1.7775 - accuracy: 0.7147 - val_loss: 2.7544 - val_accuracy: 0.6238
#
# Epoch 00008: loss improved from 1.79211 to 1.77751, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 9/20
# 40/40 [==============================] - 196s 5s/step - loss: 1.7652 - accuracy: 0.7152 - val_loss: 2.7529 - val_accuracy: 0.6266
#
# Epoch 00009: loss improved from 1.77751 to 1.76518, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 10/20
# 40/40 [==============================] - 2117s 54s/step - loss: 1.7512 - accuracy: 0.7159 - val_loss: 2.7494 - val_accuracy: 0.6263
#
# Epoch 00010: loss improved from 1.76518 to 1.75122, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 11/20
# 40/40 [==============================] - 549s 14s/step - loss: 1.7401 - accuracy: 0.7160 - val_loss: 2.7535 - val_accuracy: 0.6276
#
# Epoch 00011: loss improved from 1.75122 to 1.74009, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 12/20
# 40/40 [==============================] - 667s 17s/step - loss: 1.7285 - accuracy: 0.7163 - val_loss: 2.7461 - val_accuracy: 0.6275
#
# Epoch 00012: loss improved from 1.74009 to 1.72848, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 13/20
# 40/40 [==============================] - 183s 5s/step - loss: 1.7186 - accuracy: 0.7167 - val_loss: 2.7439 - val_accuracy: 0.6291
#
# Epoch 00013: loss improved from 1.72848 to 1.71860, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 14/20
# 40/40 [==============================] - 183s 5s/step - loss: 1.7075 - accuracy: 0.7169 - val_loss: 2.7525 - val_accuracy: 0.6278
#
# Epoch 00014: loss improved from 1.71860 to 1.70753, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 15/20
# 40/40 [==============================] - 184s 5s/step - loss: 1.6976 - accuracy: 0.7173 - val_loss: 2.7827 - val_accuracy: 0.6286
#
# Epoch 00015: loss improved from 1.70753 to 1.69760, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 16/20
# 40/40 [==============================] - 184s 5s/step - loss: 1.6883 - accuracy: 0.7179 - val_loss: 2.7509 - val_accuracy: 0.6278
#
# Epoch 00016: loss improved from 1.69760 to 1.68834, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 17/20
# 40/40 [==============================] - 184s 5s/step - loss: 1.6778 - accuracy: 0.7182 - val_loss: 2.7898 - val_accuracy: 0.6257
#
# Epoch 00017: loss improved from 1.68834 to 1.67778, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 18/20
# 40/40 [==============================] - 184s 5s/step - loss: 1.6694 - accuracy: 0.7182 - val_loss: 2.7443 - val_accuracy: 0.6287
#
# Epoch 00018: loss improved from 1.67778 to 1.66945, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 19/20
# 40/40 [==============================] - 184s 5s/step - loss: 1.6608 - accuracy: 0.7184 - val_loss: 2.8063 - val_accuracy: 0.6275
#
# Epoch 00019: loss improved from 1.66945 to 1.66080, saving model to ./model_trained_3_may_simple.hdf5
# Epoch 20/20
# 40/40 [==============================] - 185s 5s/step - loss: 1.6487 - accuracy: 0.7190 - val_loss: 2.7812 - val_accuracy: 0.6277
#
# Epoch 00020: loss improved from 1.66080 to 1.64867, saving model to ./model_trained_3_may_simple.hdf5

# %%
plots=PLOTS()
# Out:
# Instancia de la clase PLOTS creada

# %%
plots.plot_history(history)

# %%
model_file = './model_trained_3_may_simple.hdf5'
callback=[ModelCheckpoint(filepath=model_file, monitor='loss', verbose=1, save_best_only=True)]

# Train the neural network
simple_rnn_model = simple_model(
    tmp_x.shape,
    max_spanish_sequence_length,
    english_vocab_size,
    spanish_vocab_size)

# %% [markdown]
# En esta sección se crean finalmente distintos modelos que permitirán el entrenamiento. Para ello, es necesario en primer lugar dividir el conjunto de datos en __training__ y __test__ con ayuda de la función _train_test_split_ como se muestra a continuación:

# %%
train, test = train_test_split(data_eng_spa_processed, test_size=0.2, random_state = 12)

# %% [markdown]
# Seguidamente, se llama a una función definida en el archivo _text.py_: _encode_sequences_ para preparar las secuencias. También realizará el relleno de secuencia hasta una longitud máxima de oración como se mencionó anteriormente.
#
# Se codificarán oraciones en __español__ como __secuencias de entrada__ y oraciones en __inglés__ como __secuencias objetivo__. Se realizará tanto para conjuntos de datos de prueba como para conjuntos de test.

# %%
# prepare training data
trainX = utils.encode_sequences(esp_tokenizer, esp_length, train[:, 1])
trainY = utils.encode_sequences(eng_tokenizer, eng_length, train[:, 0])
# Out:
# [[   1   10 1574 ...    0    0    0]
#  [4836    4    6 ...    0    0    0]
#  [  14 4963    0 ...    0    0    0]
#  ...
#  [  43  199 1665 ...    0    0    0]
#  [  18   12   15 ...    8 1196    0]
#  [   2  240 1475 ...    0    0    0]]
# 40000
# [[   3  182   10 ...    0    0    0]
#  [   1 1094    6 ...    0    0    0]
#  [  50  101    9 ...    0    0    0]
#  ...
#  [  44  444  432 ...    0    0    0]
#  [  22    4  123 ...  213    0    0]
#  [   1  202 2244 ...    0    0    0]]
# 40000

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (40000, 8)
# (40000, 8)

# %%
# prepare validation data
testX = utils.encode_sequences(esp_tokenizer, esp_length, test[:, 1])
testY = utils.encode_sequences(eng_tokenizer, eng_length, test[:, 0])
# Out:
# [[  53   43   28 ...    0    0    0]
#  [ 233    4    1 ...    0    0    0]
#  [ 108 8599    0 ...    0    0    0]
#  ...
#  [9604  115  974 ...    0    0    0]
#  [1347   55  598 ...    0    0    0]
#  [   2   31 6750 ...    0    0    0]]
# 10000
# [[  36   16   40 ...    0    0    0]
#  [   1   37    3 ...    0    0    0]
#  [   2   99 1339 ...    0    0    0]
#  ...
#  [  56 1781   29 ...    0    0    0]
#  [  33    2  217 ...    0    0    0]
#  [   1  867   42 ...    0    0    0]]
# 10000

# %%
print(testX.shape)
print(testY.shape)
# Out:
# (10000, 8)
# (10000, 8)

# %% [markdown]
# ### 4.2.1 Model Architecture and Training

# %%
# build NMT model
def build_model(in_vocab, out_vocab, in_timesteps, out_timesteps, units):
    model = Sequential()
    model.add(Embedding(in_vocab, units, input_length=in_timesteps, mask_zero=True))
    model.add(LSTM(units))
    model.add(RepeatVector(out_timesteps))    
    model.add(LSTM(units, return_sequences=True))
    model.add(Dense(out_vocab, activation='softmax'))
    return model

# %% [markdown]
# Details about the RepeatVector :  https://campus.datacamp.com/courses/machine-translation-in-python/implementing-an-encoder-decoder-model-with-keras?ex=6

# %%
print('La longitud del vocabulario inglés es: {}'.format(eng_vocab_size))
print('La longitud del vocabulario español es: {}'.format(esp_vocab_size))
print('La longitud máxima definida para el vocavularion inglés es: {}'.format(eng_length))
print('La longitud máxima definida para el vocavularion español es: {}'.format(esp_length))
# Out:
# La longitud del vocabulario inglés es: 6942
# La longitud del vocabulario español es: 14196
# La longitud máxima definida para el vocavularion inglés es: 8
# La longitud máxima definida para el vocavularion español es: 8

# %%
model = build_model(esp_vocab_size, eng_vocab_size, esp_length, eng_length, 512)
rms = optimizers.RMSprop(lr=0.001)
model.compile(optimizer=rms, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Se ha utilizado __ 'sparse_categorical_crossentropy' __ como la función de pérdida porque permite usar la secuencia de destino tal como está en lugar de usar un formato como _one-hot-encoding_. El _one-hot-encoding_ de las secuencias de destino con un vocabulario tan grande podría consumir toda la memoria de nuestro sistema.
#
# Por tanto, una vez se ha definido la arquitectura así como el optimizador y la función de pérdida, se procede a entrenar el modelo. Se entrena durante 30 épocas y con un _batch_size_ de 512. También se usa __ModelCheckpoint() __ para guardar el mejor modelo con la menor pérdida de validación.

# %%
best_model_file = './model_trained_3_may.hdf5'
callback=[ModelCheckpoint(filepath=best_model_file, monitor='loss', verbose=1, save_best_only=True)]


#checkpoint = [ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min'), ModelCheckpoint(filename, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')]


history = model.fit(trainX, trainY.reshape(trainY.shape[0], trainY.shape[1], 1), 
          epochs=40, batch_size=512, 
          validation_split = 0.2, verbose=0,callbacks=callback)
# Out:
# Epoch 00001: loss improved from inf to 3.93048, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00002: loss improved from 3.93048 to 3.24360, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00003: loss improved from 3.24360 to 3.08999, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00004: loss improved from 3.08999 to 2.94808, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00005: loss improved from 2.94808 to 2.79886, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00006: loss improved from 2.79886 to 2.64722, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00007: loss improved from 2.64722 to 2.50301, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00008: loss improved from 2.50301 to 2.36330, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00009: loss improved from 2.36330 to 2.23091, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00010: loss improved from 2.23091 to 2.10974, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00011: loss improved from 2.10974 to 1.99352, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00012: loss improved from 1.99352 to 1.88679, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00013: loss improved from 1.88679 to 1.78695, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00014: loss improved from 1.78695 to 1.69072, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00015: loss improved from 1.69072 to 1.59751, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00016: loss improved from 1.59751 to 1.50932, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00017: loss improved from 1.50932 to 1.42411, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00018: loss improved from 1.42411 to 1.34111, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00019: loss improved from 1.34111 to 1.26473, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00020: loss improved from 1.26473 to 1.18988, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00021: loss improved from 1.18988 to 1.11893, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00022: loss improved from 1.11893 to 1.04781, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00023: loss improved from 1.04781 to 0.98094, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00024: loss improved from 0.98094 to 0.91650, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00025: loss improved from 0.91650 to 0.85666, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00026: loss improved from 0.85666 to 0.79607, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00027: loss improved from 0.79607 to 0.74342, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00028: loss improved from 0.74342 to 0.69113, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00029: loss improved from 0.69113 to 0.63947, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00030: loss improved from 0.63947 to 0.59532, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00031: loss improved from 0.59532 to 0.55004, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00032: loss improved from 0.55004 to 0.50605, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00033: loss improved from 0.50605 to 0.46775, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00034: loss improved from 0.46775 to 0.42897, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00035: loss improved from 0.42897 to 0.39499, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00036: loss improved from 0.39499 to 0.36232, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00037: loss improved from 0.36232 to 0.33299, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00038: loss improved from 0.33299 to 0.30476, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00039: loss improved from 0.30476 to 0.27906, saving model to ./model_trained_3_may.hdf5
#
# Epoch 00040: loss improved from 0.27906 to 0.25153, saving model to ./model_trained_3_may.hdf5

# %% [markdown]
# ### 4.2.2 Analysis of results

# %% [markdown]
# A continuación, se crea la instancia de la clase PLOTS y se compara la pérdida del entrenamiento con la pérdida de la validación. Para ello, se llama a la función _plot_history_ definida en el archivo _text.py_ que mostrará en pantalla los gráficos de pérdida y precisión.

# %%
plots= PLOTS()
# Out:
# Instancia de la clase PLOTS creada

# %%
plots.plot_history(history)

# %%
print("Brief summary of final accuracies: \n ")
score = model.evaluate(trainX, trainY, verbose=0) 
print ("Model train data score : {} %".format(round(score[1]*100)))

score = model.evaluate(testX, testY, verbose=0) 
print ("Model test data score : {} % ".format(round(score[1]*100)))
# Out:
# Brief summary of final accuracies:
#
# Model train data score : 91 %
# Model test data score : 72 %

# %% [markdown]
# Se podría decir, a partir de los resultados obtenidos en la celda anterior, que existe cierto __overfitting__ en el modelo pues la precisión obtenida para las muestras de entrenamiento es considerablemente mayor que la obtenida para el conjunto de test. Sin embargo, la precisión obtenida para el conjunto de test no es mala pero se podría mejorar. Para ello se propondrán otro tipo de arquitecturas más adelante con el fin de intentar mejorar la precisión obtenida.

# %% [markdown]
# ### 4.2.3 Make Predictions with saved NMT model

# %% [markdown]
# A continuación, se carga el modelo entrenado anteriormente y se hacen predicciones. Para ello, hay que convertir la secuencia predicha en palabras usando la función _get_word_ definida en la clase __UTILS__ del archivo _text.py_.

# %%
model = load_model('model_trained_3_may.hdf5')
preds = model.predict_classes(testX.reshape((testX.shape[0],testX.shape[1])))

# %%
# convert predictions into text (English)
preds_text = []
for i in preds:
    temp = []
    for j in range(len(i)):
        t = get_word(i[j], eng_tokenizer)
        if j > 0:
            if (t == get_word(i[j-1], eng_tokenizer)) or (t == None):
                temp.append('')
            else:
                temp.append(t)
             
        else:
            if(t == None):
                temp.append('')
            else:
                temp.append(t)            
        
    preds_text.append(' '.join(temp))

# %% [markdown]
# A partir de las predicciones anteriores, como bien se explica al comienzo de esta sección, se llama a la función _get_word_ con el fin de convertir las secuencias a palabras.

# %%
pred_df = pd.DataFrame({'actual' : test[:,0], 'predicted' : preds_text})

# %% [markdown]
# Se crea un dataframe en el que se recogen las frases verdaderas en la primera columna y las predicciones hechas por nuestro modelo en la segunda columna.

# %%
pred_df.head(15)
# Out:
#                        actual                    predicted
# 0      they are very cheerful            theyre very
# 1                  i know tom              i know tom
# 2              you may refuse           you can smoke
# 3               thats private               thats is
# 4    tom leaped from his seat        tom leaped on his
# 5    have you ever sold a car          send me in a car
# 6   how many kids do you have  how many kids do you have
# 7    i will not let you do it          i will do you do
# 8           isnt it beautiful      isnt you beautiful
# 9    my parrot died yesterday          my mother died
# 10             i ate an apple           i ate an apple
# 11                  toms glad            tom is happy
# 12              watch my back                my  back
# 13              tom is hiding                 tom is
# 14          put it over there            put it there

# %% [markdown]
# A continuación se pueden ver distintas partes del dataframe creado, donde se pueden observar el valor actual y el predicho por el modelo. Se puede ver que, en general, las frases predichas por el modelo no difieren en gran medida de las frases reales y, por tanto, se puede entender en muchos casos el significado de las frases predichas.

# %%
pred_df.tail(15)
# Out:
#                         actual                    predicted
# 9985      do tom and mary know       does tom know mary
# 9986         tom can be clumsy        tom can be useful
# 9987     do you want to try it      do you want to try it
# 9988    do you know who he was   do you know who that was
# 9989        shes also a beauty          its is a beauty
# 9990      i love your daughter       i want his respect
# 9991        he teaches english   he often chinese paris
# 9992               i overslept           i fell asleep
# 9993   he is as poor as can be         he is as and as am
# 9994           wheres my shirt            wheres is my
# 9995     is everything ok here  is everything all right
# 9996      im sick of this game          im sick of  this
# 9997        get rid of the gun              get up the
# 9998  did you watch this movie    did you see this movie
# 9999      i bear him no malice          i have no to him

# %%
pred_df.tail(15)
# Out:
#                         actual                    predicted
# 9985      do tom and mary know       does tom know mary
# 9986         tom can be clumsy        tom can be useful
# 9987     do you want to try it      do you want to try it
# 9988    do you know who he was   do you know who that was
# 9989        shes also a beauty          its is a beauty
# 9990      i love your daughter       i want his respect
# 9991        he teaches english   he often chinese paris
# 9992               i overslept           i fell asleep
# 9993   he is as poor as can be         he is as and as am
# 9994           wheres my shirt            wheres is my
# 9995     is everything ok here  is everything all right
# 9996      im sick of this game          im sick of  this
# 9997        get rid of the gun              get up the
# 9998  did you watch this movie    did you see this movie
# 9999      i bear him no malice          i have no to him

# %%
pred_df.sample(15)
# Out:
#                         actual                 predicted
# 8709          i love this town          i like this
# 7978        i can ride a horse    you may take a taxi
# 6600              are you busy         are you busy
# 8653     youd be crazy to stay         i come be  you
# 6429          tom slugged mary     tom punched mary
# 2747    im not afraid of death  i not afraid of death
# 6712     tom left this for you          tom did for
# 3393     i found the empty box  i found the box empty
# 7676   i need to keep you safe    i need to know safe
# 1621       i told them to stop     i told him to come
# 8616              who panicked        who panicked
# 5727      how deep is the hole          what is  the
# 658   tom shredded the lettuce       tom left the on
# 6983      its a very clear day       it is a very day
# 7393   they sell fish and meat      they us and fish
